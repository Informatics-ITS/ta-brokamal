 'pye', 'preu', 'pleu', 'pyeu', 'mré', 'mlé', 'myé', 'mri', 'mli', 'myi', 'mro', 'mlo', 'myo', 'mru', 'mlu', 'myu', 'mre', 'mle', 'mye', 'mreu', 'mleu', 'myeu', 'tré', 'tlé', 'tyé', 'tri', 'tli', 'tyi', 'tro', 'tlo', 'tyo', 'tru', 'tlu', 'tyu', 'tre', 'tle', 'tye', 'treu', 'tleu', 'tyeu', 'dré', 'dlé', 'dyé', 'dri', 'dli', 'dyi', 'dro', 'dlo', 'dyo', 'dru', 'dlu', 'dyu', 'dre', 'dle', 'dye', 'dreu', 'dleu', 'dyeu', 'bré', 'blé', 'byé', 'bri', 'bli', 'byi', 'bro', 'blo', 'byo', 'bru', 'blu', 'byu', 'bre', 'ble', 'bye', 'breu', 'bleu', 'byeu', 'gré', 'glé', 'gyé', 'gri', 'gli', 'gyi', 'gro', 'glo', 'gyo', 'gru', 'glu', 'gyu', 'gre', 'gle', 'gye', 'greu', 'gleu', 'gyeu', 'jré', 'jlé', 'jyé', 'jri', 'jli', 'jyi', 'jro', 'jlo', 'jyo', 'jru', 'jlu', 'jyu', 'jre', 'jle', 'jye', 'rri', 'rli', 'ryi', 'rro', 'rlo', 'ryo', 'rru', 'rlu', 'ryu', 'rre', 'rle', 'rye', 'rreu', 'rleu', 'ryeu', 'lré', 'llé', 'lyé', 'lri', 'lli', 'lyi', 'lro', 'llo', 'lyo', 'lru', 'llu', 'lyu', 'lre', 'lle', 'lye', 'sré', 'slé', 'syé', 'sri', 'sli', 'syi', 'sro', 'slo', 'syo', 'sru', 'slu', 'syu', 'sre', 'sle', 'sye', 'sreu', 'sleu', 'syeu', 'yré', 'ylé', 'yyé', 'yri', 'yli', 'yyi', 'yro', 'ylo', 'yyo', 'yru', 'ylu', 'yyu', 'yre', 'yle', 'yye', 'yreu', 'yleu', 'yyeu', 'wré', 'wlé', 'wyé', 'wri', 'wli', 'wyi', 'wro', 'wlo', 'wyo', 'wru', 'wlu', 'wyu', 'wre', 'wle', 'wye', 'wreu', 'wleu', 'wyeu', 'hré', 'hlé', 'hyé', 'hri', 'hli', 'hyi', 'hro', 'hlo', 'hyo', 'hru', 'hlu', 'hyu', 'hre', 'hle', 'hye', 'hreu', 'hleu', 'hyeu', 'fré', 'flé', 'fyé', 'fri', 'fli', 'fyi', 'fro', 'flo', 'fyo', 'fru', 'flu', 'fre', 'fle', 'cri', 'cli', 'cyi', 'cro', 'clo', 'cyo', 'cru', 'clu', 'cyu']

# dataset generation
filename = "dataset.csv"
with open(filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["source", "target"])

    total_rrows = 0
    target_rrows = 3000

    # First ensure every token is used at least once
    for src_token in base_source_tokens:
        tgt_token = base_target_tokens[base_source_tokens.index(src_token)]
        writer.writerow([src_token.lower(), tgt_token.lower()])
        total_rrows += 1

    # Then fill remaining rows with random combinations
    while total_rrows < target_rrows:
        length = random.randint(1, 25)
        src_tokens = random.sample(base_source_tokens, k=length)
        tgt_tokens = [
            base_target_tokens[base_source_tokens.index(w)] if w in base_source_tokens else w
            for w in src_tokens
        ]
        writer.writerow([" ".join(src_tokens).lower(), " ".join(tgt_tokens).lower()])
        total_rrows += 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import numpy as np

# 1. Data Preparation
df = pd.read_csv("dataset.csv")

# Split into train and test sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

def build_vocab(tokens):
    vocab = {tok: i+4 for i, tok in enumerate(tokens)}
    vocab["<pad>"] = 0
    vocab["<sos>"] = 1
    vocab["<eos>"] = 2
    vocab["<unk>"] = 3
    return vocab

source_tokens = [t.lower() for t in df['source'].str.split().explode().unique()]
target_tokens = [t.lower() for t in df['target'].str.split().explode().unique()]
SRC_VOCAB = build_vocab(source_tokens)
TGT_VOCAB = build_vocab(target_tokens)
SRC_IVOCAB = {i: t for t, i in SRC_VOCAB.items()}
TGT_IVOCAB = {i: t for t, i in TGT_VOCAB.items()}

def encode(tokens, vocab):
    return [vocab.get(tok, vocab["<unk>"]) for tok in tokens]

class Seq2SeqDataset(Dataset):
    def __init__(self, df, src_vocab, tgt_vocab):
        self.pairs = []
        for _, row in df.iterrows():
            src = encode(row['source'].split(), src_vocab)
            tgt = [tgt_vocab["<sos>"]] + encode(row['target'].split(), tgt_vocab) + [tgt_vocab["<eos>"]]
            self.pairs.append((src, tgt))
    def __len__(self): return len(self.pairs)
    def __getitem__(self, idx): return self.pairs[idx]

def collate_fn(batch):
    srcs, tgts = zip(*batch)
    src_lens = [len(s) for s in srcs]
    tgt_lens = [len(t) for t in tgts]
    src_pad = torch.zeros(len(srcs), max(src_lens), dtype=torch.long)
    tgt_pad = torch.zeros(len(tgts), max(tgt_lens), dtype=torch.long)
    for i, (s, t) in enumerate(zip(srcs, tgts)):
        src_pad[i, :len(s)] = torch.tensor(s)
        tgt_pad[i, :len(t)] = torch.tensor(t)
    return src_pad, tgt_pad, src_lens, tgt_lens

# Use train_df and test_df to create datasets and loaders
train_dataset = Seq2SeqDataset(train_df, SRC_VOCAB, TGT_VOCAB)
test_dataset = Seq2SeqDataset(test_df, SRC_VOCAB, TGT_VOCAB)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)

# %%
# 2. Model Definition
class Encoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hid_dim, n_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim, padding_idx=SRC_VOCAB["<pad>"])
        self.lstm = nn.LSTM(emb_dim, hid_dim, n_layers, bidirectional=False, batch_first=True)
    def forward(self, src, src_lens):
        emb = self.embedding(src)
        packed = nn.utils.rnn.pack_padded_sequence(emb, src_lens, batch_first=True, enforce_sorted=False)
        outputs, (h, c) = self.lstm(packed)
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs, batch_first=True)
        return outputs, (h, c)

class BahdanauAttention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        self.attn = nn.Linear(enc_hid_dim + dec_hid_dim, dec_hid_dim)
        self.v = nn.Parameter(torch.rand(dec_hid_dim))
    def forward(self, hidden, encoder_outputs, mask):
        src_len = encoder_outputs.size(1)
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim=2)))
        energy = energy @ self.v
        energy = energy.masked_fill(mask == 0, -1e10)
        return F.softmax(energy, dim=1)

class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, enc_hid_dim, dec_hid_dim, attention, n_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim, padding_idx=TGT_VOCAB["<pad>"])
        self.lstm = nn.LSTM(emb_dim + enc_hid_dim, dec_hid_dim, n_layers, batch_first=True)
        self.fc_out = nn.Linear(dec_hid_dim + enc_hid_dim + emb_dim, vocab_size)
        self.attention = attention
    def forward(self, input, hidden, cell, encoder_outputs, mask):
        input = input.unsqueeze(1)
        emb = self.embedding(input)
        attn_weights = self.attention(hidden[-1], encoder_outputs, mask)
        attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)
        lstm_input = torch.cat((emb, attn_applied), dim=2)
        output, (hidden, cell) = self.lstm(lstm_input, (hidden, cell))
        output = output.squeeze(1)
        attn_applied = attn_applied.squeeze(1)
        emb = emb.squeeze(1)
        pred = self.fc_out(torch.cat((output, attn_applied, emb), dim=1))
        return pred, hidden, cell, attn_weights

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, src_pad_idx, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.device = device
    def create_mask(self, src):
        return (src != self.src_pad_idx)
    def forward(self, src, src_lens, tgt, teacher_forcing_ratio=0.5):
        batch_size, tgt_len = tgt.shape
        outputs = torch.zeros(batch_size, tgt_len, self.decoder.embedding.num_embeddings).to(self.device)
        encoder_outputs, (h, c) = self.encoder(src, src_lens)
        h_dec = h  # [num_layers, batch, hid_dim]
        c_dec = c
        input = tgt[:,0]
        mask = self.create_mask(src)
        for t in range(1, tgt_len):
            output, h_dec, c_dec, _ = self.decoder(input, h_dec, c_dec, encoder_outputs, mask)
            outputs[:,t] = output
            teacher_force = torch.rand(1).item() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = tgt[:,t] if teacher_force else top1
        return outputs

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
INPUT_DIM = len(SRC_VOCAB)
OUTPUT_DIM = len(TGT_VOCAB)
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
HID_DIM = 256

attn = BahdanauAttention(HID_DIM, HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, HID_DIM, attn)
model = Seq2Seq(enc, dec, SRC_VOCAB["<pad>"], device).to(device)

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index=TGT_VOCAB["<pad>"])

# Metric evaluation functions
def levenshtein(ref, hyp):
    m, n = len(ref), len(hyp)
    dp = np.zeros((m + 1, n + 1), dtype=int)
    for i in range(m + 1):
        dp[i][0] = i
    for j in range(n + 1):
        dp[0][j] = j
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if ref[i - 1] == hyp[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = 1 + min(dp[i - 1][j], dp[i][j - 1], dp[i - 1][j - 1])
    return dp[m][n]

def compute_cer(ref, hyp):
    ref = ref.replace(' ', '')
    hyp = hyp.replace(' ', '')
    if len(ref) == 0:
        return 0.0 if len(hyp) == 0 else 1.0
    return levenshtein(ref, hyp) / len(ref)

def compute_wer(ref, hyp):
    ref_words = ref.split()
    hyp_words = hyp.split()
    if len(ref_words) == 0:
        return 0.0 if len(hyp_words) == 0 else 1.0
    return levenshtein(ref_words, hyp_words) / len(ref_words)

# Use train_loader for training
best_loss = float('inf')
best_model_state = None

for epoch in range(150):
    model.train()
    total_loss = 0
    batch_losses = []
    for src, tgt, src_lens, tgt_lens in train_loader:
        src, tgt = src.to(device), tgt.to(device)
        optimizer.zero_grad()
        output = model(src, src_lens, tgt)
        output_dim = output.shape[-1]
        output = output[:,1:].reshape(-1, output_dim)
        tgt = tgt[:,1:].reshape(-1)
        loss = criterion(output, tgt)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        batch_losses.append(loss.item())
    avg_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")
    # Save the model if it has the lowest loss so far
    if avg_loss < best_loss:
        best_loss = avg_loss
        best_model_state = model.state_dict()

# After training, load the best model
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    print(f"Loaded best model with loss: {best_loss:.4f}")
# Out:
# Epoch 1, Loss: 6.6756
# Epoch 2, Loss: 6.2311
# Epoch 3, Loss: 5.7348
# Epoch 4, Loss: 5.0829
# Epoch 5, Loss: 4.3800
# Epoch 6, Loss: 3.6226
# Epoch 7, Loss: 2.8817
# Epoch 8, Loss: 2.1622
# Epoch 9, Loss: 1.5788
# Epoch 10, Loss: 1.1578
# Epoch 11, Loss: 0.8129
# Epoch 12, Loss: 0.5232
# Epoch 13, Loss: 0.3874
# Epoch 14, Loss: 0.2312
# Epoch 15, Loss: 0.1605
# Epoch 16, Loss: 0.1142
# Epoch 17, Loss: 0.0897
# Epoch 18, Loss: 0.0691
# Epoch 19, Loss: 0.0653
# Epoch 20, Loss: 0.0804
# Epoch 21, Loss: 0.0843
# Epoch 22, Loss: 0.0628
# Epoch 23, Loss: 0.0725
# Epoch 24, Loss: 0.0710
# Epoch 25, Loss: 0.0729
# Epoch 26, Loss: 0.0598
# Epoch 27, Loss: 0.0388
# Epoch 28, Loss: 0.0473
# Epoch 29, Loss: 0.0353
# Epoch 30, Loss: 0.0280
# Epoch 31, Loss: 0.0297
# Epoch 32, Loss: 0.0242
# Epoch 33, Loss: 0.0201
# Epoch 34, Loss: 0.0200
# Epoch 35, Loss: 0.0147
# Epoch 36, Loss: 0.0327
# Epoch 37, Loss: 0.0403
# Epoch 38, Loss: 0.0488
# Epoch 39, Loss: 0.0709
# Epoch 40, Loss: 0.1021
# Epoch 41, Loss: 0.0708
# Epoch 42, Loss: 0.0478
# Epoch 43, Loss: 0.0315
# Epoch 44, Loss: 0.0148
# Epoch 45, Loss: 0.0093
# Epoch 46, Loss: 0.0079
# Epoch 47, Loss: 0.0040
# Epoch 48, Loss: 0.0033
# Epoch 49, Loss: 0.0039
# Epoch 50, Loss: 0.0036
# Epoch 51, Loss: 0.0022
# Epoch 52, Loss: 0.0019
# Epoch 53, Loss: 0.0016
# Epoch 54, Loss: 0.0015
# Epoch 55, Loss: 0.0014
# Epoch 56, Loss: 0.0013
# Epoch 57, Loss: 0.0012
# Epoch 58, Loss: 0.0011
# Epoch 59, Loss: 0.0011
# Epoch 60, Loss: 0.0010
# Epoch 61, Loss: 0.0010
# Epoch 62, Loss: 0.0009
# Epoch 63, Loss: 0.0009
# Epoch 64, Loss: 0.0008
# Epoch 65, Loss: 0.0008
# Epoch 66, Loss: 0.0007
# Epoch 67, Loss: 0.0007

# %%
def translate(model, src_sentence, max_len=30):
    model.eval()
    src_tokens = encode(src_sentence.lower().split(), SRC_VOCAB)
    src_tensor = torch.tensor(src_tokens).unsqueeze(0).to(device)
    src_lens = [len(src_tokens)]
    with torch.no_grad():
        encoder_outputs, (h, c) = model.encoder(src_tensor, src_lens)
        h_dec = h
        c_dec = c
        input = torch.tensor([TGT_VOCAB["<sos>"]]).to(device)
        mask = model.create_mask(src_tensor)
        result = []
        for _ in range(max_len):
            output, h_dec, c_dec, _ = model.decoder(input, h_dec, c_dec, encoder_outputs, mask)
            top1 = output.argmax(1)
            if top1.item() == TGT_VOCAB["<eos>"]:
                break
            result.append(TGT_IVOCAB[top1.item()])
            input = top1
    return " ".join(result)

# Example usage:
print(translate(model, "ka na pa ka_hh ka_rr ka_ng ka_rrr ka_yyy ka_lll nga_ee"))
# Out:
# ka na pa kah kar kang kra kya kla nge

# %%
    # Metric evaluation on the test set (unseen data)
    model.eval()
    total_cer = 0
    total_wer = 0
    n_samples = 0
    with torch.no_grad():
        example_printed = 0
        for src, tgt, src_lens, tgt_lens in test_loader:
            src = src.to(device)
            for i in range(src.size(0)):
                src_sentence = ' '.join([SRC_IVOCAB[idx.item()] for idx in src[i] if idx.item() != SRC_VOCAB["<pad>"]])
                tgt_sentence = ' '.join([TGT_IVOCAB[idx.item()] for idx in tgt[i] if idx.item() not in [TGT_VOCAB["<pad>"], TGT_VOCAB["<sos>"], TGT_VOCAB["<eos>"]]])
                pred_sentence = translate(model, src_sentence)
                cer = compute_cer(tgt_sentence, pred_sentence)
                wer = compute_wer(tgt_sentence, pred_sentence)
                total_cer += cer
                total_wer += wer
                n_samples += 1
                # Print a few examples
                if example_printed < 100:
                    print(f"Example {example_printed+1}:")
                    print(f"  Source:    {src_sentence}")
                    print(f"  Target:    {tgt_sentence}")
                    print(f"  Predicted: {pred_sentence}")
                    print(f"  CER: {cer:.2%}, WER: {wer:.2%}\n")
                    example_printed += 1
    print(f"CER: {total_cer/n_samples:.2%}, WER: {total_wer/n_samples:.2%}")
# Out:
# Example 1:
#   Source:    na_lll ta_oo_lll la_oo_rr xa_ee o sa_ex_yyy na_uu_ng za_eueu_hh ca_uu_ng ma_ex_yyy ga_yyy sa_ex ba_eueu_rr va_ii
#   Target:    nla tlo lor xe o syé nung zeuh cung myé gya sé beur vi
#   Predicted: nla tlo lor xe syé syé nung zeuh cung myé gya sé beur vi
#   CER: 7.32%, WER: 7.14%
#
# Example 2:
#   Source:    ja_yyy ca_ex_hh pa_ex_rrr ra_eueu ma_ee_hh fa_oo ba_ii_yyy ga_ii_ng xa_ex_ng wa_oo_hh ra_uu_rrr ha_rr fa_ex sa_ee_yyy ja_ex_rr qa_ee_ng ma_ii_yyy kha_pamaeh ma_ee_ng ha_ex_rr ba_ii_ng ra_eueu_rrr
#   Target:    jya céh pré reu meh fo byi ging xéng woh rru har fé sye jér qeng myi kh meng hér bing rreu
#   Predicted: jya céh pré reu meh fo byi ging xéng woh rru har fé sye jér qeng myi kh meng hér bing rreu
#   CER: 0.00%, WER: 0.00%
#
# Example 3:
#   Source:    pa_ee_rrr sya_oo_rr ra_ex lima ma_ii_ng ka_eueu_hh ta_ii_ng pa_ex_rrr ma_uu_rrr qa_yyy da_ii_rr sa_ii_hh
#   Target:    pre syor ré 5 ming keuh ting pré mru qya dir sih
#   Predicted: pre syor ré 5 ming keuh ting pré mru qya dir sih
#   CER: 0.00%, WER: 0.00%
#
# Example 4:
#   Source:    ba_ee_rr
#   Target:    ber
#   Predicted: ber
#   CER: 0.00%, WER: 0.00%
#
# Example 5:
#   Source:    va_rrr ha_ex_rrr ra_uu_rrr i_ng wa_uu_ng sa_ii_rrr qa_pamaeh na_oo_rrr ta_eueu sa_ii_lll xa_hh
#   Target:    vra hré rru ing wung sri q nro teu sli xah
#   Predicted: vra hré rru ing wung sri q nro teu sli xah
#   CER: 0.00%, WER: 0.00%
#
# Example 6:
#   Source:    nya_hh nya_eueu_rr za_yyy ha_ee_hh fa_oo_rrr ma_eueu ja_ex_rrr ca_uu za_uu sa_eueu_ng ja_oo_rrr ra_uu_ng
#   Target:    nyah nyeur zya heh fro meu jré cu zu seung jro rung
#   Predicted: nyah nyeur zya heh fro meu jré cu zu seung jro rung
#   CER: 0.00%, WER: 0.00%
#
# Example 7:
#   Source:    la_oo_rr
#   Target:    lor
#   Predicted: lor
#   CER: 0.00%, WER: 0.00%
#
# Example 8:
#   Source:    za_oo qa_ii_ng pa_eueu_yyy i_ng nga_oo_ng ca_ex_hh ga_oo sa_yyy ta_lll hiji va_oo_rr pa_uu_lll sya_uu_rr sa_oo_rrr da_eueu_lll ya_eueu_rr sa_ex_rr ka_yyy ja_ng da_yyy na_oo_lll
#   Target:    zo qing pyeu ing ngong céh go sya tla 1 vor plu syur sro dleu yeur sér kya jang dya nlo
#   Predicted: zo qing pyeu ing ngong céh go sya tla 1 vor plu syur sro dleu yeur sér kya jang dya nlo
#   CER: 0.00%, WER: 0.00%
#
# Example 9:
#   Source:    ga_uu_hh wa_oo_ng fa_ee_ng wa_hh
#   Target:    guh wong feng wah
#   Predicted: guh wong feng wah
#   CER: 0.00%, WER: 0.00%
#
# Example 10:
#   Source:    pa_ee_hh
#   Target:    peh
#   Predicted: peh
#   CER: 0.00%, WER: 0.00%
#
# Example 11:
#   Source:    i_hh
#   Target:    ih
#   Predicted: ih
#   CER: 0.00%, WER: 0.00%
#
# Example 12:
#   Source:    ca_pamaeh ba_uu_lll ra_ii_rrr sa_uu_rrr
#   Target:    c blu rri sru
#   Predicted: c blu rri sru
#   CER: 0.00%, WER: 0.00%
#
# Example 13:
#   Source:    pa_uu_hh o_ng va_rr kha_eueu_ng nya ta_uu_rrr la_uu_lll pa_ii_rr la_pamaeh ha_pamaeh ya wa_ii_hh la_ex
#   Target:    puh ong var kheung nya tru llu pir l h ya wih lé
#   Predicted: puh ong var kheung nya tru llu pir l h ya wih lé
#   CER: 0.00%, WER: 0.00%
#
# Example 14:
#   Source:    da_ii_yyy la_ee_yyy xa_ng opat ya_ee ba_yyy za_oo_rr ja_uu_yyy la_pamaeh pa_lll ba_eueu_hh ca_uu_rrr ra_oo_rr nya_uu ba_ii_lll qa_oo
#   Target:    dyi lye xang 4 ye bya zor jyu l pla beuh cru ror nyu bli qo
#   Predicted: dyi lye xang 4 ye bya zor jyu l pla beuh cru ror nyu bli qo
#   CER: 0.00%, WER: 0.00%
#
# Example 15:
#   Source:    wa_ii_rr ga_ee_yyy ra va_oo_ng ta_ee ga_uu_lll da_ee_ng na_oo za_rr ha_ii_rrr salapan da_uu_hh ga_ee_hh sya_ii ba_uu_lll kha_pamaeh ha_eueu_rr ya_ii_hh
#   Target:    wir gye ra vong te glu deng no zar hri 9 duh geh syi blu kh heur yih
#   Predicted: wir gye ra vong te glu vung no zar hri 9 duh geh syi blu kh heur yih
#   CER: 3.92%, WER: 5.56%
#
# Example 16:
#   Source:    ja_oo_ng fa_ii_rr sa_eueu_yyy ta_ee_ng wa_ii fa_ex_lll ya_hh ma_ee_rr ya_ii_yyy sa_ee_rr wa_oo_ng ha_yyy
#   Target:    jong fir syeu teng wi flé yah mer yyi ser wong hya
#   Predicted: jong fir syeu teng wi flé yah mer yyi ser wong hya
#   CER: 0.00%, WER: 0.00%
#
# Example 17:
#   Source:    la_ee_rr
#   Target:    ler
#   Predicted: ler
#   CER: 0.00%, WER: 0.00%
#
# Example 18:
#   Source:    qa_oo_ng la_eueu_rr sa_uu_lll ya_oo_ng va_yyy pa_ex da_hh ga_ii_yyy fa_ii ma_ex ha_oo_hh ba_ee_rrr ga_ee_rrr ya_pamaeh sya_oo_hh nga_ii sa_uu_ng wa_ex_ng nga_oo_ng ya_lll ha_rrr za_eueu_rr na_ex_hh na_ii
#   Target:    qong leur slu yong vya pé dah gyi fi mé hoh bre gre y syoh ngi sung wéng ngong yla hra zeur néh ni
#   Predicted: qong leur slu yong vya pé dah gyi fi mé hoh bre gre y syoh ngi sung wéng ngong yla hra zeur néh ni
#   CER: 0.00%, WER: 0.00%
#
# Example 19:
#   Predicted: nya m hung nir nyur yang pa tla ruh lla tri pra fyo sri syoh dlu pu yéh tu coh
#   CER: 0.00%, WER: 0.00%
#
# Example 26:
#   Source:    xa_ee sya_uu za_ee_ng fa_ex_ng da_ee_lll ja_ex_rr sya_hh la_ex_rrr ga_eueu_hh a_hh ba_ii_yyy fa_oo_rrr pa_oo_rr sa_ii_lll sa_ee_ng ta_ex_yyy ka_yyy ja_eueu ra_oo_hh qa_ee_hh ma_uu_lll na ta_oo
#   Target:    xe syu zeng féng dle jér syah lré geuh ah byi fro por sli seng tyé kya jeu roh qeh mlu na to
#   Predicted: xe syu zeng féng dle jér mo lré geuh ah byi fro por sli seng tyé kya jeu roh qeh mlu na to
#   CER: 5.71%, WER: 4.35%
#
# Example 27:
#   Source:    na_lll xa_ex_rr ba_ii wa_oo_lll sa_oo_ng sa_ee_rr ca_yyy nya_uu_hh tilu na_ii_hh za_oo_rr ka_yyy sa_ii_lll wa_uu_lll fa_ii_yyy sya_ee qa_uu_hh ta_ii_yyy da_uu_lll ca_ii
#   Target:    nla xér bi wlo song ser cya nyuh 3 nih zor kya sli wlu fyi sye quh tyi dlu ci
#   Predicted: nla xér bi léng song ser cya nyuh 3 nih zor kya sli wlu fyi sye quh tyi dlu ci
#   CER: 6.90%, WER: 5.00%
#
# Example 28:
#   Source:    ba_ee_ng da_lll ka_uu_rr da_uu_hh na_ex_ng
#   Target:    beng dla kur duh néng
#   Predicted: beng dla kur duh néng
#   CER: 0.00%, WER: 0.00%
#
# Example 29:
#   Source:    va_ii_rr ca_ii_ng ra_ee ja_ex_hh ca_ng kha_rr wa_rrr ya_ii_lll fa_ii_hh ba_ii qa_ee_rr wa_ee_rr
#   Target:    vir cing re jéh cang khar wra yli fih bi qer wer
#   Predicted: vir cing re jéh cang khar wra yli fih bi qer wer
#   CER: 0.00%, WER: 0.00%
#
# Example 30:
#   Source:    da_pamaeh pa_ex_yyy pa_ee_ng qa_uu
#   Target:    d pyé peng qu
#   Predicted: d pyé peng qu
#   CER: 0.00%, WER: 0.00%
#
# Example 31:
#   Source:    ha_oo
#   Target:    ho
#   Predicted: ho
#   CER: 0.00%, WER: 0.00%
#
# Example 32:
#   Source:    ga_ee ra_ex va_rr ba_uu_hh ha_ee_rrr nya_ee_ng u_ng ra_oo ha_oo_yyy qa_ex_ng qa_uu_hh ma_ee_lll la_pamaeh fa_rr ra_ee_yyy ha_ee_lll va_ii_ng ma_rrr ma_uu_rrr kha_ee_rr
#   Target:    ge ré var buh hre nyeng ung ro hyo qéng quh mle l far rye hle ving mra mru kher
#   Predicted: ge ré var buh hre nyeng ung ro hyo qéng quh mle l far rye hle ving mra mru kher
#   CER: 0.00%, WER: 0.00%
#
# Example 33:
#   Source:    ga_eueu_ng na_oo_ng la_uu_rrr ga_eueu_yyy
#   Target:    geung nong lru gyeu
#   Predicted: geung nong lru gyeu
#   CER: 0.00%, WER: 0.00%
#
# Example 34:
#   Source:    nga_ng wa_ex_yyy hiji ba_rr la_ii_lll qa_eueu_rr ba_ii da_uu_lll qa_ex_rr kha_rr ba_eueu
#   Target:    ngang wyé 1 bar lli qeur bi dlu qér khar beu
#   Predicted: ngang wyé 1 bar lli qeur bi dlu qér khar beu
#   CER: 0.00%, WER: 0.00%
#
# Example 35:
#   Source:    la_ii pa_uu_lll sa_ex_rr ka_ex_lll ca_oo_yyy ma_eueu_yyy ja_ee_yyy ha_eueu_rr la_ex_hh wa_ii ta_oo_rrr qa_uu_ng xa_rrr ra_oo_rr pa_ee_ng fa_pamaeh ra_ee_yyy ja_ex_ng
#   Target:    li plu sér klé cyo myeu jye heur léh wi tro qung xra ror peng f rye jéng
#   Predicted: li plu sér klé cyo myeu jye heur léh wi tro qung xra ror peng f rye jéng
#   CER: 0.00%, WER: 0.00%
#
# Example 36:
#   Source:    sa_uu_lll ca_ii_ng sya_ex_rr nya_uu_hh sa_ex_lll pa_ex_ng la_oo_hh fa_ii ya_oo_yyy fa_yyy ga_ii_yyy salapan pa_eueu_rrr ra_hh ja_eueu_ng na_oo ca_eueu_hh ra_eueu_yyy ga_ee_hh va_oo_rr ja_uu_rr da_ee_rrr
#   Target:    slu cing syér nyuh slé péng loh fi yyo fya gyi 9 preu rah jeung no ceuh ryeu geh vor jur dre
#   Predicted: slu cing hleu nyuh slé péng loh fi yyo fya gyi 9 preu rah jeung no ceuh ryeu geh vor jur dre
#   CER: 5.63%, WER: 4.55%
#
# Example 37:
#   Source:    ka ca_uu_ng sa_ii_hh hiji nya_ii_ng
#   Target:    ka cung sih 1 nying
#   Predicted: ka cung sih 1 nying
#   CER: 0.00%, WER: 0.00%
#
# Example 38:
#   Source:    ta_oo
#   Target:    to
#   Predicted: to
#   CER: 0.00%, WER: 0.00%
#
# Example 39:
#   Source:    nga_ng ca_oo_rrr sa_oo_ng ja_ex_hh ra_eueu_rrr za_yyy ja_lll ka_ex_rr fa_eueu_rr ya_hh ra_lll wa_ii_rr ba_ex_rr ka_pamaeh za_uu_ng wa_eueu_hh nga_ex_rr ga fa_ii_lll pa_oo_ng sa_ee_rrr ma_oo_rrr
#   Target:    ngang cro song jéh rreu zya jla kér feur yah rla wir bér k zung weuh ngér ga fli pong sre mro
#   Predicted: ngang cro song jéh rreu zya jla kér feur yah rla wir bér k zung weuh ngér ga fli pong sre mro
#   CER: 0.00%, WER: 0.00%
#
# Example 40:
#   Source:    pa_ee_ng da_ii_ng va_ee_ng na_uu_yyy ga_eueu_rrr za_ii_rr ja_ex
#   Target:    peng ding veng nyu greu zir jé
#   Predicted: peng ding veng nyu greu zir jé
#   CER: 0.00%, WER: 0.00%
#
# Example 41:
#   Source:    pa_oo_lll ya_oo_ng ha_oo_lll fa_oo_lll da_eueu nga ga_uu la_ii_hh ga_ex_ng ha_uu_lll la_oo_ng
#   Target:    plo yong hlo flo deu nga gu lih géng hlu long
#   Predicted: plo yong hlo flo deu nga gu lih géng hlu long
#   CER: 0.00%, WER: 0.00%
#
# Example 42:
#   Source:    eu
#   Target:    eu
#   Predicted: eu
#   CER: 0.00%, WER: 0.00%
#
# Example 43:
#   Source:    fa_uu_lll ga_ii ca_uu_lll za_yyy ja ma_lll sa_rr ha_yyy ca_uu_hh ya_ii_yyy da_yyy la_ii_lll ba_ee
#   Target:    flu gi clu zya ja mla sar hya cuh yyi dya lli be
#   Predicted: flu gi clu zya ja mla sar hya cuh yyi dya lli be
#   CER: 0.00%, WER: 0.00%
#
# Example 44:
#   Source:    ga_ex ra_ii_rr
#   Target:    gé rir
#   Predicted: gé rir
#   CER: 0.00%, WER: 0.00%
#
# Example 45:
#   Source:    ra_ii fa_eueu_ng
#   Target:    ri feung
#   Predicted: ri feung
#   CER: 0.00%, WER: 0.00%
#
# Example 46:
#   Source:    a_rr
#   Target:    ar
#   Predicted: ar
#   CER: 0.00%, WER: 0.00%
#
# Example 47:
#   Source:    wa ya_ee_ng ma_eueu_rr ya_ii
#   Target:    wa yeng meur yi
#   Predicted: wa yeng meur yi
#   CER: 0.00%, WER: 0.00%
#
# Example 48:
#   Source:    ba_oo_rrr ja_oo_yyy xa nga_ii_ng ya_uu_yyy ka_ex_hh ja_ee ja_ex_hh sa_ii_rrr sa_ee_ng ka_ee_rr ya_uu_ng fa_oo_yyy na_ii_rr ja_uu_lll ja_hh ca_yyy nga_oo_hh ba_ex_rrr da_ii_ng ka_oo_hh
#   Target:    bro jyo xa nging yyu kéh je jéh sri seng ker yung fyo nir jlu jah cya ngoh bré ding koh
#   Predicted: bro jyo xa nging yyu kéh je jéh sri seng ker yung fyo nir jlu jah cya ngoh bré ding koh
#   CER: 0.00%, WER: 0.00%
#
# Example 49:
#   Source:    ca_eueu_ng ca_eueu_hh pa_pamaeh ya_ee_lll na_ee xa_ii_ng ya_ex ga_uu_hh sya_eueu_ng fa_ee_rr sa_uu_ng ra_eueu_ng ba_uu_rr
#   Target:    ceung ceuh p yle ne xing yé guh syeung fer sung reung bur
#   Predicted: ceung ceuh p yle ne xing yé guh syeung fer sung reung bur
#   CER: 0.00%, WER: 0.00%
#
# Example 50:
#   Source:    va_ee la_eueu_ng pa_hh ha_yyy ta_uu_yyy da_uu_ng ra_lll ta_uu va_ee_rr xa_ex_hh ba_eueu
#   Target:    ve leung pah hya tyu dung rla tu ver xéh beu
#   Predicted: ve leung pah hya tyu dung rla tu ver xéh beu
#   CER: 0.00%, WER: 0.00%
#
# Example 51:
#   Source:    la_oo_ng wa_eueu_lll sya_ee_rr
#   Target:    long wleu syer
#   Predicted: long wleu syer
#   CER: 0.00%, WER: 0.00%
#
# Example 52:
#   Source:    ba_ee_yyy kha_ee_ng pa_ex_lll ha_oo_rr sya_eueu sa_ex_yyy za_eueu_hh da_eueu_yyy pa_ex nya_ii nya_ii_hh ma_ii_hh ka_eueu_rr ta_lll xa_ii_ng ka_eueu ha ra_ee_rr ca_uu_rrr
#   Target:    bye kheng plé hor syeu syé zeuh dyeu pé nyi nyih mih keur tla xing keu ha rer cru
#   Predicted: bye kheng plé hor syeu syé zeuh dyeu pé nyi nyih mih keur tla xing keu ha rer cru
#   CER: 0.00%, WER: 0.00%
#
# Example 53:
#   Source:    za_eueu nga_ex_rr ha_uu_lll ta_ee_yyy ka_eueu kha_ee_ng ca_lll ja_ee sa_uu_hh da_eueu_lll da i_hh nga_ii_hh da_eueu_rrr pa_ii_hh la_ex_yyy kha_ee sya_ex_hh ca_oo_yyy
#   Target:    zeu ngér hlu tye keu kheng cla je suh dleu da ih ngih dreu pih lyé khe syéh cyo
#   Predicted: zeu ngér hlu tye woh kheng cla je suh dleu da ih ngih dreu pih lyé khe syéh cyo
#   CER: 4.92%, WER: 5.26%
#
# Example 54:
#   Source:    ga_oo_yyy ha_uu_rrr wa_uu_rrr pa_eueu_rr ga_oo_lll
#   Target:    gyo hru wru peur glo
#   Predicted: gyo hru wru peur glo
#   CER: 0.00%, WER: 0.00%
#
# Example 55:
#   Source:    ca_ii_ng da_uu_ng ta_oo_rrr nga_ng ja_ng na_ii_ng ca_uu_yyy na_pamaeh ha_ee_rr
#   Target:    cing dung tro ngang jang ning cyu n her
#   Predicted: cing dung tro ngang jang ning cyu n her
#   CER: 0.00%, WER: 0.00%
#
# Example 56:
#   Source:    ha_oo_rr fa_uu_rrr wa_ex_lll pa_ii_rrr kha_ex za_pamaeh ra_eueu ka_uu_ng ha_uu_ng pa_eueu nga_eueu ga_uu_rrr fa_ee_hh ha_uu_yyy ya_uu_yyy qa_uu kha_oo nga_ex ja_ee na_ng ma_uu ba_ii_hh sa_uu_lll
#   Target:    hor fru wlé pri khé z reu kung hung peu ngeu gru feh hyu yyu qu kho ngé je nang mu bih slu
#   Predicted: hor fru wlé pri khé z reu kung hung peu ngeu gru feh hyu yyu qu kho ngé je nang mu bih slu
#   CER: 0.00%, WER: 0.00%
#
# Example 57:
#   Source:    za_ex fa_ee_rr ra_oo_lll ma_ee_hh kha_pamaeh ma_hh ka_ex genep pa_ee_rr na_uu_lll ga_ii_lll na_ii_yyy xa_ee
#   Target:    zé fer rlo meh kh mah ké 6 per nlu gli nyi xe
#   Predicted: zé fer rlo meh kh mah ké 6 per nlu gli nyi xe
#   CER: 0.00%, WER: 0.00%
#
# Example 58:
#   Source:    ga_eueu_rrr nga_ee_hh nya_eueu_ng da_uu_rrr da_ee_rrr ka_uu_rr za_eueu_rr pa_oo nga_uu ta_oo_rrr nga_uu_ng la_ee ma_ex_ng
#   Target:    greu ngeh nyeung dru dre kur zeur po ngu tro ngung le méng
#   Predicted: greu ngeh nyeung dru dre kur zeur po ngu tro ngung le méng
#   CER: 0.00%, WER: 0.00%
#
# Example 59:
#   Source:    nya_ng sa_eueu_rrr sa_oo_rrr
#   Target:    nyang sreu sro
#   Predicted: nyang sreu sro
#   CER: 0.00%, WER: 0.00%
#
# Example 60:
#   Source:    fa_ee_rrr qa_eueu_hh na_uu_rr ga_ee_yyy da_uu_yyy la_uu_ng sya_oo_hh ga_uu_ng fa_ee_lll ha_ee_yyy ja_oo_rrr wa_ee_ng ba_ii_ng da_uu_hh ta_uu_hh ga_eueu_rrr ya_ee_rr fa_ii_rrr ja_ii_hh na_ee_rrr é ma_rrr da_ex da_hh ga_uu_yyy
#   Target:    fre qeuh nur gye dyu lung syoh gung fle hye jro weng bing duh tuh greu yer fri jih nre é mra dé dah gyu
#   Predicted: fre qeuh nur gye zing lung syoh gung fle hye jro weng bing duh tuh greu yer fri jih nre é mra gyu dah gyu
#   CER: 8.86%, WER: 8.00%
#
# Example 61:
#   Source:    ga_ex_rr ra_uu_rr ja_uu_rr la_oo_lll ta_ee_rrr nga_pamaeh da_ii_hh nya_uu_rr eu ra_eueu_rr wa_ii_lll fa_ex_hh source qa_eueu_ng fa_hh ta_ex_rr
#   Target:    gér rur jur llo tre ng dih nyur eu reur wli féh target qeung fah tér
#   Predicted: gér rur jur llo tre ng dih nyur eu reur wli féh target qeung fah tér
#   CER: 0.00%, WER: 0.00%
#
# Example 62:
#   Source:    wa_ii_yyy ga_ee_rr ra_uu_hh sa_ii_yyy ta_ee_yyy ya_ex_ng ga_uu_lll ba_eueu_lll na_yyy kha da_ex_ng nga_ii_hh qa_lll
#   Target:    wyi ger ruh syi tye yéng glu bleu nya kha déng ngih qla
#   Predicted: wyi ger ruh syi tye yéng glu bleu nya kha déng ngih qla
#   CER: 0.00%, WER: 0.00%
#
# Example 63:
#   Source:    ka_ex_hh ka_ii_rrr ra_ii_ng wa_ex_yyy fa_ex_ng ma_ee_ng ra_ee_rr ga_ex_rrr ga_ee_hh nga_ee_rr e_rr sya_eueu_ng ca_uu_ng nya qa_ex_ng wa_oo_hh ya_oo_ng
#   Target:    kéh kri ring wyé féng meng rer gré geh nger er syeung cung nya qéng woh yong
#   Predicted: kéh kri qéh wyé féng meng rer gré geh nger er syeung cung nya qéng woh yong
#   CER: 6.67%, WER: 5.88%
#
# Example 64:
#   Source:    ga_ng
#   Target:    gang
#   Predicted: gang
#   CER: 0.00%, WER: 0.00%
#
# Example 65:
#   Source:    ta_ex_ng ra_uu_lll ra_ee_yyy sa_rr
#   Target:    téng rlu rye sar
#   Predicted: téng rlu rye sar
#   CER: 0.00%, WER: 0.00%
#
# Example 66:
#   Source:    ga_ee_rr na_yyy
#   Target:    ger nya
#   Predicted: ger nya
#   CER: 0.00%, WER: 0.00%
#
# Example 67:
#   Source:    ca_ee_hh va_oo_rr la_ex_yyy ka_ex_lll sa_ii_rrr ca_eueu_rr ma_eueu_rrr ja_ee_lll la_oo kha_oo ba_oo_lll pa_oo_hh sya_eueu_ng fa_oo_yyy ya_ii ca_ee wa_ee_lll sa_ex_rr ta_eueu_lll
#   Target:    ceh vor lyé klé sri ceur mreu jle lo kho blo poh syeung fyo yi ce wle sér tleu
#   Predicted: ceh vor lyé klé sri ceur mreu jle lo kho blo poh syeung fyo yi ce wle sér tleu
#   CER: 0.00%, WER: 0.00%
#
# Example 68:
#   Source:    sa_oo ga_ex na_ee_lll ca_uu la_rrr fa_ee_hh ga ma_uu ra_ii_lll ca_lll sa_ng la_uu_rr va_lll ka_ii_yyy la_ii wa_ex_rrr sya_eueu_rr a da_eueu xa_hh ra_hh
#   Target:    so gé nle cu lra feh ga mu rli cla sang lur vla kyi li wré syeur a deu xah rah
#   Predicted: so gé nle cu lra feh ga mu rli cla sang lur vla kyi li wré syeur a deu xah rah
#   CER: 0.00%, WER: 0.00%
#
# Example 69:
#   Source:    ca_ii sya_eueu_rr ha_ee kha_ee_hh nya_oo_hh da_oo_lll za_eueu
#   Target:    ci syeur he kheh nyoh dlo zeu
#   Predicted: ci syeur he kheh nyoh dlo wru
#   CER: 8.70%, WER: 14.29%
#
# Example 70:
#   Source:    ba_hh e_rr qa_ex_rr ka_oo_yyy ra_ex_hh qa_lll sa_oo_yyy ra_eueu_rr xa_ex_hh ba_ee_lll na_eueu ga_ex za_ii_rr fa_ee_rr kha_rr ba_uu_rrr ta_ex_rrr na_ii_rrr na_ex_ng sya_uu kha_ee_hh sa_ex_rr la_ee
#   Target:    bah er qér kyo réh qla syo reur xéh ble neu gé zir fer khar bru tré nri néng syu kheh sér le
#   Predicted: bah er qér kyo réh qla syo reur xéh ble neu gé zir fer khar bru tré nri néng syu kheh sér le
#   CER: 0.00%, WER: 0.00%
#
# Example 71:
#   Source:    ga_eueu_lll va_oo_hh wa_uu_rrr ta_hh
#   Target:    gleu voh wru tah
#   Predicted: gleu voh wru tah
#   CER: 0.00%, WER: 0.00%
#
# Example 72:
#   Source:    qa_eueu_hh
#   Target:    qeuh
#   Predicted: qeuh
#   CER: 0.00%, WER: 0.00%
#
# Example 73:
#   Source:    ra_oo_rr ha_uu ka_rr ka_lll va_lll va_eueu_rr sya_eueu_rr opat wa_ex wa_ii_hh sa_eueu
#   Target:    ror hu kar kla vla veur syeur 4 wé wih seu
#   Predicted: ror hu kar kla vla veur syeur 4 wé wih seu
#   CER: 0.00%, WER: 0.00%
#
# Example 74:
#   Source:    wa_ee ya_eueu_lll la_ii da_pamaeh sya_rr genep ja_uu_lll ra_rrr kha_ex ma_ex_yyy ja_ex_rr ba_ex_lll wa_ee_ng la_ii_lll ha_oo_rrr ta nya_ii_ng ba_uu_hh
#   Target:    we yleu li d syar 6 jlu rra khé myé jér blé weng lli hro ta nying buh
#   Predicted: we yleu li d syar 6 jlu rra khé myé jér blé weng lli hro ta nying buh
#   CER: 0.00%, WER: 0.00%
#
# Example 75:
#   Source:    ha_ng ra_eueu_hh na_rr ga_eueu_lll ka_ee_rrr sa_ii_hh nya_eueu_rr ya_ii_hh pa_rr na_uu_yyy za_ng la_ex la_ee_lll ta_ex_hh pa_ex_yyy za_ex qa_uu_rr na_eueu_rrr qa_eueu ga_ee_lll
#   Target:    hang reuh nar gleu kre sih nyeur yih par nyu zang lé lle téh pyé zé qur nreu qeu gle
#   Predicted: hang reuh nar gleu kre sih nyeur yih par nyu zang lé lle téh pyé zé qur gle feh gle
#   CER: 7.69%, WER: 10.00%
#
# Example 76:
#   Source:    da_pamaeh da_uu_rr ta_ex na_hh source va_uu ba_ex_ng ka_ee_rr ja ja_uu_rr nya_rr qa_ng
#   Target:    d dur té nah target vu béng ker ja jur nyar qang
#   Predicted: d dur té nah target vu béng ker ja jur nyar qang
#   CER: 0.00%, WER: 0.00%
#
# Example 77:
#   Source:    ra_eueu_rrr
#   Target:    rreu
#   Predicted: rreu
#   CER: 0.00%, WER: 0.00%
#
# Example 78:
#   Source:    ja_ex_rrr la_uu_hh sa_ex_rr za_eueu_ng ha_ex_rrr ya_ng sya_ee va_uu_rr ja_ee_lll ba ta_ex_rrr fa_ii
#   Target:    jré luh sér zeung hré yang sye vur jle ba tré fi
#   Predicted: jré luh sér zeung hré yang sye vur jle ba tré fi
#   CER: 0.00%, WER: 0.00%
#
# Example 79:
#   Source:    sya_ng ga_eueu na_ii_ng fa_oo_ng ha_eueu_ng ma_uu_lll qa_ex_ng ma_ex_yyy da_hh ca_ee_ng pa_eueu_rr fa_uu_hh ya_oo ta_eueu_hh ta_lll ga_ex_rrr
#   Target:    syang geu ning fong heung mlu qéng myé dah ceng peur fuh yo teuh tla gré
#   Predicted: syang geu ning fong heung mlu qéng myé dah ceng peur fuh yo teuh tla gré
#   CER: 0.00%, WER: 0.00%
#
# Example 80:
#   Source:    ha_oo_rrr xa_lll qa_oo_hh va_uu_hh sya_rr wa_rrr ja_uu kha_ee_ng za_ii_ng ya_oo_yyy fa_ng la_uu_hh dua
#   Target:    hro xla qoh vuh syar wra ju kheng zing yyo fang luh 2
#   Predicted: hro xla qoh vuh syar wra ju kheng zing yyo fang luh 2
#   CER: 0.00%, WER: 0.00%
#
# Example 81:
#   Source:    ya_lll ya_ii_hh ga_uu_hh la_oo_hh ba_uu_yyy wa_oo_hh za_ee la_ex_rrr sya_uu_rr ga_oo_lll ma_ii_rrr da_uu qa_ii_hh
#   Target:    yla yih guh loh byu woh ze lré syur glo mri du qih
#   Predicted: yla yih guh loh byu woh ze lré syur glo mri du qih
#   CER: 0.00%, WER: 0.00%
#
# Example 82:
#   Source:    ja_oo_yyy
#   Target:    jyo
#   Predicted: jyo
#   CER: 0.00%, WER: 0.00%
#
# Example 83:
#   Source:    wa_ii_hh dua ma_eueu pa_ex_hh ga_ex_rrr sa_uu_rrr ma_ee_hh ya_oo_rrr ra nga_rr ta_eueu ma_eueu_lll da_ii_rr ma_eueu_ng ma_uu_rrr wa_oo_hh kha_rr
#   Target:    wih 2 meu péh gré sru meh yro ra ngar teu mleu dir meung mru woh khar
#   Predicted: wih 2 meu péh gré sru meh yro ra ngar teu mleu dir meung mru woh khar
#   CER: 0.00%, WER: 0.00%
#
# Example 84:
#   Source:    qa_eueu ha_eueu_rr va ba_oo_yyy nga_hh pa_oo_hh za_ex_rr fa_ii_yyy ja
#   Target:    qeu heur va byo ngah poh zér fyi ja
#   Predicted: qeu heur va byo ngah poh zér cér ja
#   CER: 11.11%, WER: 11.11%
#
# Example 85:
#   Source:    nga_ex_ng
#   Target:    ngéng
#   Predicted: ngéng
#   CER: 0.00%, WER: 0.00%
#
# Example 86:
#   Source:    ca_ii_rr nga_oo nga_ii_hh kha_ii ma_ex_ng va_ex_hh na_eueu_ng
#   Target:    cir ngo ngih khi méng véh neung
#   Predicted: cir ngo ngih khi méng véh neung
#   CER: 0.00%, WER: 0.00%
#
# Example 87:
#   Source:    nga_eueu_hh
#   Target:    ngeuh
#   Predicted: ngeuh
#   CER: 0.00%, WER: 0.00%
#
# Example 88:
#   Source:    va ta_yyy la_ee_rr na_ii_lll ra_ee_lll nya_ee_rr xa sa_eueu_lll wa_ex_yyy nga_eueu_ng sya_hh ya_ee_hh sa_ii ya_ex ma_ee_yyy ra_eueu_hh sya_ee_ng wa_ex_lll ka_ii ha_ee_hh ja_ee_hh
#   Target:    va tya ler nli rle nyer xa sleu wyé ngeung syah yeh si yé mye reuh syeng wlé ki heh jeh
#   Predicted: va tya ler nli rle nyer xa sleu wyé ngeung syah yeh si yé mye reuh syeng wlé ki heh jeh
#   CER: 0.00%, WER: 0.00%
#
# Example 89:
#   Source:    ta_ee_lll ta_uu ha_ex_yyy
#   Target:    tle tu hyé
#   Predicted: tle tu hyé
#   CER: 0.00%, WER: 0.00%
#
# Example 90:
#   Source:    ba_eueu_rrr ga_uu_lll nga_ii_ng ha_eueu_lll ya_ng wa_ee_rrr kha_eueu_rr ka_ii wa_uu_yyy ba_uu_hh pa_ee_lll qa_ee_ng
#   Target:    breu glu nging hleu yang wre kheur ki wyu buh ple qeng
#   Predicted: breu glu nging hleu yang wre kheur ki wyu buh qeng
#   CER: 6.98%, WER: 8.33%
#
# Example 91:
#   Source:    na_lll sa_ee_ng ta_eueu_rrr sya_ng pa_ee_rr ja_ex_yyy enol ra_ee_rr u_hh nya_ex_hh ta_ee ma_ii_lll ma_ii_rrr xa_pamaeh fa_ii_rr
#   Target:    nla seng treu syang per jyé 0 rer uh nyéh te mli mri x fir
#   Predicted: nla seng treu syang per jyé 0 rer uh nyéh te mli mri x fir
#   CER: 0.00%, WER: 0.00%
#
# Example 92:
#   Source:    za_ee_rr u_rr ya_ii_lll va_ii_ng ra_uu_rrr nya_oo_ng da_ii_ng ma_ii_lll nga_uu_hh ca_ii_rrr qa_hh ga_ex ca_eueu_ng wa_uu_ng va_ii fa_uu_lll na_uu_rr fa_ng fa_uu_hh na_uu_ng ga_ee_ng ya_oo_rr pa_ee_ng fa_eueu_rr
#   Target:    zer ur yli ving rru nyong ding mli nguh cri qah gé ceung wung vi flu nur fang fuh nung geng yor peng feur
#   Predicted: zer ur yli ving rru nyong ding mli nguh cri qah gé ceung wung vi flu nur fang fuh nung geng feur peng feur
#   CER: 3.66%, WER: 4.17%
#
# Example 93:
#   Source:    ra_oo_rrr ca_ex_ng ba_ex_rrr nya_rr ta_rrr ba_ii_ng u_rr ca_oo_yyy fa_oo_hh sa_ex_rrr ja_lll sa_ee_lll ta_uu_hh nya_eueu_hh
#   Target:    rro céng bré nyar tra bing ur cyo foh sré jla sle tuh nyeuh
#   Predicted: rro céng bré nyar tra bing ur cyo foh sré jla sle tuh nyeuh
#   CER: 0.00%, WER: 0.00%
#
# Example 94:
#   Source:    ha_ee_lll
#   Target:    hle
#   Predicted: hle
#   CER: 0.00%, WER: 0.00%
#
# Example 95:
#   Source:    ca_ex_hh pa_uu_rr nya_ex nga_rr ja_uu_rr ca_yyy ha_eueu_ng ya_ex_yyy ka_uu_yyy kha_rr da_uu_hh ga_ex ra_uu_yyy
#   Target:    céh pur nyé ngar jur cya heung yyé kyu khar duh gé ryu
#   Predicted: céh pur nyé ngar jur cya heung yyé kyu khar xér gé ryu
#   CER: 7.14%, WER: 7.69%
#
# Example 96:
#   Source:    ba_rrr ca_uu_rr pa_rr ca_oo u_hh fa_ex_rrr ra_ex ya_uu_yyy wa_yyy ya_uu_lll sa_ng nya_oo_rr wa_ee_rr ja_uu_ng
#   Target:    bra cur par co uh fré ré yyu wya ylu sang nyor wer jung
#   Predicted: bra cur par co uh fré ré yyu wya ylu sang nyor wer jung
#   CER: 0.00%, WER: 0.00%
#
# Example 97:
#   Source:    ha_ii_lll xa_ex_rr na_uu_lll genep
#   Target:    hli xér nlu 6
#   Predicted: hli xér nlu 6
#   CER: 0.00%, WER: 0.00%
#
# Example 98:
#   Source:    ka_oo_hh ha_hh wa_ee_lll ka_eueu_rr ma_oo_rrr wa_eueu_rrr ma_ee_rrr nga_uu ja_ex_rr ma ma_ee_hh ta_ee_rr u_hh ka_oo_rrr ba_uu_rrr ha_ii_rrr sya_uu_ng ha_oo_lll
#   Target:    koh hah wle keur mro wreu mre ngu jér ma meh ter uh kro bru hri syung hlo
#   Predicted: koh gir wle keur mro wreu mre ngu jér ma meh ter uh kro bru hri syung hlo
#   CER: 5.36%, WER: 5.56%
#
# Example 99:
#   Source:    qa_ii_rr ba_eueu_rr ma_yyy ra_eueu_rrr ya_rr ra_ee_rrr da_ii_hh ja_ee_rr
#   Target:    qir beur mya rreu yar rre dih jer
#   Predicted: qir beur mya rreu yar rre dih jer
#   CER: 0.00%, WER: 0.00%
#
# Example 100:
#   Source:    la_uu_rr ja_uu_rr na_ee_yyy ha_ee_lll sya sa_ex_hh ba_eueu_lll ma_ii_rr ta_ex kha_uu
#   Target:    lur jur nye hle sya séh bleu mir té khu
#   Predicted: lur jur nye hle sya séh bleu mir té khu
#   CER: 0.00%, WER: 0.00%
#
# CER: 2.11%, WER: 2.09%

# %%
# Save only the model weights
torch.save(model.state_dict(), "seq2seq_model_uni_attention_10k.pt")

# %%
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    # Optionally, save epoch, loss, etc.
    'epoch': 243,
    'loss': 0.0009,
}, "seq2seq_checkpoint_uni_attention.pt")

# %%
# Load checkpoint
checkpoint = torch.load("/content/seq2seq_checkpoint_uni_attention.pt", map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device)
model.eval()

# Evaluation
total_cer = 0
total_wer = 0
n_samples = 0
example_printed = 0

with torch.no_grad():
    for src, tgt, src_lens, tgt_lens in test_loader:
        src = src.to(device)
        for i in range(src.size(0)):
            src_sentence = ' '.join([SRC_IVOCAB[idx.item()] for idx in src[i] if idx.item() != SRC_VOCAB["<pad>"]])
            tgt_sentence = ' '.join([TGT_IVOCAB[idx.item()] for idx in tgt[i] if idx.item() not in [TGT_VOCAB["<pad>"], TGT_VOCAB["<sos>"], TGT_VOCAB["<eos>"]]])
            pred_sentence = translate(model, src_sentence)
            cer = compute_cer(tgt_sentence, pred_sentence)
            wer = compute_wer(tgt_sentence, pred_sentence)
            total_cer += cer
            total_wer += wer
            n_samples += 1
            if example_printed < 100:
                print(f"Example {example_printed+1}:")
                print(f"  Source:    {src_sentence}")
                print(f"  Target:    {tgt_sentence}")
                print(f"  Predicted: {pred_sentence}")
                print(f"  CER: {cer:.2%}, WER: {wer:.2%}\n")
                example_printed += 1

print(f"Evaluation from checkpoint at epoch 243:")
print(f"  CER: {total_cer/n_samples:.2%}")
print(f"  WER: {total_wer/n_samples:.2%}")
# Out:
# Example 1:
#   Source:    ra_uu_rr ya_ii_yyy
#   Target:    rur yyi
#   Predicted: rur
#   CER: 50.00%, WER: 50.00%
#
# Example 2:
#   Source:    ga na_oo_yyy ma_ex_ng fa_ee_hh nya_ex_rr nga_ee_hh sa_ex_rr
#   Target:    ga nyo méng feh nyér ngeh sér
#   Predicted: ga nyo méng feh nyér ngeh sér
#   CER: 0.00%, WER: 0.00%
#
# Example 3:
#   Source:    va_ee_hh fa_lll pa_uu_rr ba_ex_ng va_ii_hh kha_ex_ng e_rr ka_oo_rrr na_oo_lll la_ii_hh wa_ex ra_rrr fa_rrr na_uu_ng ya_eueu_rr xa_ee qa_oo ta_uu ra_uu_ng ja_rr sya_ee_hh ja_yyy pa_oo_yyy
#   Target:    veh fla pur béng vih khéng er kro nlo lih wé rra fra nung yeur xe qo tu rung jar syeh jya pyo
#   Predicted: veh fla pur béng vih khéng er kro nlo lih wé rra fra nung yeur xe qo tu rung jya rung jya song
#   CER: 12.68%, WER: 13.04%
#
# Example 4:
#   Source:    nya_oo fa_pamaeh ta_yyy ga_uu_lll na_oo_rrr fa ya_pamaeh nya_ex na_ex_ng nya_ee_ng ta_oo_yyy
#   Target:    nyo f tya glu nro fa y nyé néng nyeng tyo
#   Predicted: nyo f tya gar nro fa y nyé néng nyeng tyo
#   CER: 6.45%, WER: 9.09%
#
# Example 5:
#   Source:    xa_ii_rr ca_oo_rr wa_oo_yyy kha_ex_hh wa_ee_rrr ga_uu_lll ba_uu sa_oo_lll xa_eueu eu u_ng ja_rrr genep na_uu_rrr na_eueu_ng ja_oo_lll ba_oo_hh ta_eueu ma_rrr i fa_eueu za_ee_rr
#   Target:    xir cor wyo khéh wre glu bu slo xeu eu ung jra 6 nru neung jlo boh teu mra i feu zer
#   Predicted: xir cor wyo khéh wre glu bu slo xeu eu ung jra 6 nru neung jlo boh teu mra ngéh feu zer
#   CER: 6.35%, WER: 4.55%
#
# Example 6:
#   Source:    ka_uu_yyy sya_ex nga_ng ya_pamaeh ca_rr ja_ex ra_yyy ra_eueu_rr fa_oo_hh sa_ex_rr nya_ex_rr va_ex ja_ii_yyy
#   Target:    kyu syé ngang y car jé rya reur foh sér nyér vé jyi
#   Predicted: kyu syé ngang y car jé rya reur foh sér nyér vé jyi
#   CER: 0.00%, WER: 0.00%
#
# Example 7:
#   Source:    la_oo_rr
#   Target:    lor
#   Predicted: lor
#   CER: 0.00%, WER: 0.00%
#
# Example 8:
#   Source:    ja_pamaeh sa_ex_yyy va_oo nya_eueu_hh ma_eueu_yyy wa_ee
#   Target:    j syé vo nyeuh myeu we
#   Predicted: j syé vo nyeuh khé we
#   CER: 23.53%, WER: 16.67%
#
# Example 9:
#   Source:    i ra_rrr nya_uu_rr ba_ee_rrr va_hh ha_ee_ng kha_ee_ng
#   Target:    i rra nyur bre vah heng kheng
#   Predicted: i rra nyur bre vah heng kheng
#   CER: 0.00%, WER: 0.00%
#
# Example 10:
#   Source:    pa_ee_hh
#   Target:    peh
#   Predicted: peh
#   CER: 0.00%, WER: 0.00%
#
# Example 11:
#   Source:    va_hh ca_oo_ng ja_ii_hh ga_ex_rrr ha_uu_ng ga_uu_hh wa_yyy sa_uu_rr sa_eueu_hh ja_oo_ng da_ee ma_ee_rr ga_ii_hh wa_ex_rr ha_ng sya_eueu
#   Target:    vah cong jih gré hung guh wya sur seuh jong de mer gih wér hang syeu
#   Predicted: vah cong jih gré hung guh wya sur seuh jong de mer gih wér hang syeu
#   CER: 0.00%, WER: 0.00%
#
# Example 12:
#   Source:    na_uu_yyy ba_oo_ng fa_eueu_rr ya_eueu_hh ga_ii_hh ta_ex za_eueu ba_uu_ng ka_ng sa_oo_rr sa_oo_yyy ta_ii_hh ca_rr ha_lll pa_rr kha_pamaeh na_eueu_rr fa_oo_rr kha_ee ha_ii_ng ca_ii ha_uu_lll
#   Target:    nyu bong feur yeuh gih té zeu bung kang sor syo tih car hla par kh neur for khe hing ci hlu
#   Predicted: nyu bong feur yeuh ting té fang bung kang sor syo tih car hla par kh neur for khe hing hlu hlu
#   CER: 14.29%, WER: 13.64%
#
# Example 13:
#   Source:    ca_pamaeh ya_ee_lll qa_ex sya_ii_ng na_rr sa_rrr sa_eueu la_ex_lll i_hh fa_oo_ng a_hh la_ee_rr ha_eueu_rrr da_lll nga_ex_ng ba_ee za_oo_rr va_rr ya_ii_lll ha_ng ba_oo_hh ra_ii_rr xa_rr ta_ee_yyy
#   Target:    c yle qé sying nar sra seu llé ih fong ah ler hreu dla ngéng be zor var yli hang boh rir xar tye
#   Predicted: c yle qé fah nar sra seu llé ih fong ah ler hreu dla ngéng be zor var yli yli ba jeu jer tye
#   CER: 21.92%, WER: 20.83%
#
# Example 14:
#   Source:    ra_ii_rr ga_ee ra_eueu_rr ta_ii_rrr fa_ii_yyy ta_eueu_yyy pa_eueu_rr
#   Target:    rir ge reur tri fyi tyeu peur
#   Predicted: rir ge reur tri fyi tyeu peur
#   CER: 0.00%, WER: 0.00%
#
# Example 15:
#   Source:    pa_hh i_hh ha_uu_ng na_ii_yyy da_eueu_hh ya_oo_hh nga_ee_hh pa_ee_lll ga_ee_rr sa_ee nga_oo_rr pa_lll pa_ee_rr sa_uu ba_ee_rr pa_uu_rrr u ga_rrr
#   Target:    pah ih hung nyi deuh yoh ngeh ple ger se ngor pla per su ber pru u gra
#   Predicted: pah ih hung nyi beuh yoh ngeh ple ger se ngor pla per su ber pru u gra
#   CER: 1.89%, WER: 5.56%
#
# Example 16:
#   Source:    xa ga_oo_rr ja_ee ma_ii ya_ii_rrr ca da_ee ta_ex_yyy fa_ex_rr ka_oo_lll va_eueu_rr ga_oo_yyy fa_ii_lll ba_ii_rrr sa_ee_rrr ya_eueu wa_uu xa_ii_hh na_ng qa_ii_rr da_hh ja_eueu_rr qa_ee_ng
#   Target:    xa gor je mi yri ca de tyé fér klo veur gyo fli bri sre yeu wu xih nang qir dah jeur qeng
#   Predicted: xa gor je mi bih ca de hro fér klo veur gyo fli bri sre yeu wu xih nang qir dah jeur qeng
#   CER: 8.96%, WER: 8.70%
#
# Example 17:
#   Source:    la_ee_rr
#   Target:    ler
#   Predicted: ler
#   CER: 0.00%, WER: 0.00%
#
# Example 18:
#   Source:    wa_ng ma_ee_lll ra_oo_lll sa_oo_hh sya_ee da_ii
#   Target:    wang mle rlo soh sye di
#   Predicted: wang mle rlo soh sye di
#   CER: 0.00%, WER: 0.00%
#
# Example 19:
#   Source:    ha_ee_rrr ha_eueu_hh ka_ex_yyy kha_ex_ng ra_uu_rr wa_ii_hh ja_ii_hh la_ii_yyy ka_uu_lll ca_ee_rr ga_hh ca_ii_hh wa_uu_lll na_eueu_lll ca_rrr fa_uu_ng na_ex_rrr sa_ee_rrr ma_eueu_hh tujuh sa_ex va_eueu_rr qa ya_eueu_rr
#   Target:    hre heuh kyé khéng rur wih jih lyi klu cer gah cih wlu nleu cra fung nré sre meuh 7 sé veur qa yeur
#   Predicted: hre jé kyé khéng rur wih jih lyi klu cer gah cih wlu nleu cra fung nré sre meuh 7 wyo cah qa yeur
#   CER: 13.16%, WER: 12.50%
#
# Example 20:
#   Source:    fa_ii_lll va_oo_rr ha_ee_rrr pa_lll ra_oo_yyy qa_ng va_eueu_ng ta_ii_hh wa_ee_yyy ha_uu_hh ra_oo_lll ma_ee_hh ha_oo_hh ya_oo_rrr da_uu_hh ta_oo_rrr sya_rr ja_rrr fa_uu_rrr ha_ii_rr ma_uu_rrr
#   Target:    fli vor hre pla ryo qang veung tih wye huh rlo meh hoh yro duh tro syar jra fru hir mru
#   Predicted: fli oh hre pla ryo qang veung tih wye huh rlo meh hoh yro duh 6 syar jra mru hir mru
#   CER: 8.96%, WER: 14.29%
#
# Example 21:
#   Source:    za_pamaeh opat sya_pamaeh fa_eueu za_ex_hh ra_rr ta_ee ka_ee_rrr fa_uu_ng sya_eueu_rr ga_ex_lll i_ng
#   Target:    z 4 sy feu zéh rar te kre fung syeur glé ing
#   Predicted: z 4 sy feu zéh rar te kre dyeu syeur glé ing
#   CER: 12.12%, WER: 8.33%
#
# Example 22:
#   Source:    fa_eueu_ng ca_ex_rr nga_uu sa_oo_rr za_ng wa_ii_yyy la_ee_lll
#   Target:    feung cér ngu sor zang wyi lle
#   Predicted: feung cér ngu sor zang wyi lle
#   CER: 0.00%, WER: 0.00%
#
# Example 23:
#   Source:    nga_pamaeh ba_uu_yyy ha_oo wa_ee qa_eueu_rr nya_ex kha_eueu_ng pa_oo_rr ja_ii_ng da_ii_lll ta_ex_rrr ba_oo_yyy fa_ee_rr sya_uu da_yyy ta_ee_yyy sa_ii_lll
#   Target:    ng byu ho we qeur nyé kheung por jing dli tré byo fer syu dya tye sli
#   Predicted: ng byu ho we qeur nyé kheung por jing dli tré byo fer syu dya tye sli
#   CER: 0.00%, WER: 0.00%
#
# Example 24:
#   Source:    qa_eueu_hh kha ha_eueu_ng za_ee_ng la_ee_rr ba_uu_lll ya_ng ja_oo_lll ga_uu_ng la_eueu ba_ee_rr la_uu_lll
#   Target:    qeuh kha heung zeng ler blu yang jlo gung leu ber llu
#   Predicted: qeuh kha heung zeng ler blu yang jlo gung leu ber llu
#   CER: 0.00%, WER: 0.00%
#
# Example 25:
#   Source:    ca_oo_ng ja_ex ka_hh wa_oo_hh ka_pamaeh nga_ii ka_eueu_rr la_ex_rrr ka_oo ra_ex_rr ja_pamaeh va_oo_hh ta_ex_rrr
#   Target:    cong jé kah woh k ngi keur lré ko rér j voh tré
#   Predicted: cong jé kah woh k ngi keur lré ko rér j voh tré
#   CER: 0.00%, WER: 0.00%
#
# Example 26:
#   Source:    sa_uu_ng
#   Target:    sung
#   Predicted: sung
#   CER: 0.00%, WER: 0.00%
#
# Example 27:
#   Source:    ka_ii_hh ra_ii_yyy
#   Target:    kih ryi
#   Predicted: kih ryi
#   CER: 0.00%, WER: 0.00%
#
# Example 28:
#   Source:    ja_ex_rr ha_uu_rr ya_ee_hh nga qa_uu_hh ja_ee_rr va_ee
#   Target:    jér hur yeh nga quh jer ve
#   Predicted: jér hur yeh nga quh jer ve
#   CER: 0.00%, WER: 0.00%
#
# Example 29:
#   Source:    ta_ee wa_eueu_ng za_eueu_hh na_eueu_lll xa_ii_ng ma_eueu_rr ba_uu_rr da_ex_lll xa_eueu ka_uu_yyy va_ex_hh nya wa_lll ba_ng sa_ee_rr fa_ee_hh ra_uu na_eueu_ng ba_ii_yyy ra_oo_rrr la_uu_rrr
#   Target:    te weung zeuh nleu xing meur bur dlé xeu kyu véh nya wla bang ser feh ru neung byi rro lru
#   Predicted: te weung zeuh jah dong meur bur dlé xeu kyu véh nya wla bang ser feh ru neung byi rro lru
#   CER: 8.57%, WER: 9.52%
#
# Example 30:
#   Source:    ya_eueu_hh qa_uu_rr sa_ii_rrr ra_ee_lll kha_eueu_rr za_uu_rr ma_ii_rr ya_eueu_rrr la_ng ya_ex_yyy ha_ex_ng ya_oo_hh
#   Target:    yeuh qur sri rle kheur zur mir yreu lang yyé héng yoh
#   Predicted: yeuh qur sri rle kheur zur mir yreu lang be héng yoh
#   CER: 7.14%, WER: 8.33%
#
# Example 31:
#   Source:    ha_oo
#   Target:    ho
#   Predicted: ho
#   CER: 0.00%, WER: 0.00%
#
# Example 32:
#   Source:    kha_eueu_hh
#   Target:    kheuh
#   Predicted: kheuh
#   CER: 0.00%, WER: 0.00%
#
# Example 33:
#   Source:    wa_oo ya_eueu_lll ba_eueu sya_ii_ng ra_uu la_oo_rr
#   Target:    wo yleu beu sying ru lor
#   Predicted: wo yleu beu sying ru lor
#   CER: 0.00%, WER: 0.00%
#
# Example 34:
#   Source:    kha_ex_hh ka_ii_rrr la_oo_ng
#   Target:    khéh kri long
#   Predicted: khéh kri long
#   CER: 0.00%, WER: 0.00%
#
# Example 35:
#   Source:    nga_ee_ng ka_eueu_yyy za_oo_rr o_ng ka_uu_hh ba_uu_lll ra_rrr fa_ex_hh fa_ee nya_oo ka_ee_rrr ha_uu sya_ee a_ng ha ja_ex_lll ca_ee ya_ex_yyy ta_ii_ng na_ee_yyy ka_ex pa_rr ja_ii_lll ba_oo_rrr
#   Target:    ngeng kyeu zor ong kuh blu rra féh fe nyo kre hu sye ang ha jlé ce yyé ting nye ké par jli bro
#   Predicted: ngeng kyeu zor ong dyo blu rra féh fe nyo kre hu fi ang ha jlé ce yyé ting nuh qah par jli bro
#   CER: 15.49%, WER: 16.67%
#
# Example 36:
#   Source:    ta_oo_rr ta_ii fa_ex_yyy ma_ex_lll ra_ee na_ex_hh ja_yyy wa_ex_rrr ma_ee sa_uu_rrr kha_eueu_rr
#   Target:    tor ti fyé mlé re néh jya wré me sru kheur
#   Predicted: tor ti fyé mlé re néh jya wré me sru kheur
#   CER: 0.00%, WER: 0.00%
#
# Example 37:
#   Source:    xa_eueu kha_ex pa_eueu_lll ma_oo_lll sya_oo_rr la_uu_hh ma_ii_rrr ra_ng fa_eueu_hh wa_rrr da_uu_lll ga_ee_rrr la_ee_rr ya_ex ja_eueu_hh nya_uu_rr ca_ee
#   Target:    xeu khé pleu mlo syor luh mri rang feuh wra dlu gre ler yé jeuh nyur ce
#   Predicted: xeu khé pleu mlo syor luh mri rang feuh wra dlu da ler yé jeuh nyur ce
#   CER: 5.45%, WER: 5.88%
#
# Example 38:
#   Source:    ta_oo
#   Target:    to
#   Predicted: to
#   CER: 0.00%, WER: 0.00%
#
# Example 39:
#   Source:    na_ex_rr la_eueu_rr da_ee ya_ee_rr ma_oo_lll ba_ng
#   Target:    nér leur de yer mlo bang
#   Predicted: nér hre de hyeu mlo bang
#   CER: 31.58%, WER: 33.33%
#
# Example 40:
#   Source:    ha_oo_ng ka_ee_yyy a_ng pa_oo_rr ka_ex_hh
#   Target:    hong kye ang por kéh
#   Predicted: hong kye ang qang kéh
#   CER: 25.00%, WER: 20.00%
#
# Example 41:
#   Source:    ra_ii qa_eueu_rr na_ii_lll wa_ii_rrr ca_ex_hh ta_ex ba_ex_hh ca_lll na
#   Target:    ri qeur nli wri céh té béh cla na
#   Predicted: ri qeur nli wri céh té béh cla na
#   CER: 0.00%, WER: 0.00%
#
# Example 42:
#   Source:    eu
#   Target:    eu
#   Predicted: eu
#   CER: 0.00%, WER: 0.00%
#
# Example 43:
#   Source:    ca_eueu za_hh da_oo_yyy da_ee_lll xa_ex kha_ex_hh ha_ii na_ex_yyy sa_oo_ng qa_ii_ng la_oo_rrr fa_oo pa_ii_yyy za_uu_ng va_ee_hh ya_ex_rr ha_oo la_ex_yyy ta_ex_hh
#   Target:    ceu zah dyo dle xé khéh hi nyé song qing lro fo pyi zung veh yér ho lyé téh
#   Predicted: ceu zah dyo dle xé khéh hi nyé song qing ngéh fo pyi zung veh yér ho lyé téh
#   CER: 7.02%, WER: 5.26%
#
# Example 44:
#   Source:    da_ii_rrr a la_oo_rrr la_ee_ng ma_ex_rr da_oo_rr ra_ng la_ex_hh ta_uu_yyy sya_oo_rr ha_yyy ta_ii_rr i_ng ka_ex_ng da_uu_rrr ya_uu_rr sa_lll ja_oo_ng da_ee_rrr nya_eueu ka_ee_hh
#   Target:    dri a lro leng mér dor rang léh tyu syor hya tir ing kéng dru yur sla jong dre nyeu keh
#   Predicted: dri a lro leng mér dor nye yih tyu syor hya tir ing kéng dru yur sla jong dre nyeu keh
#   CER: 8.96%, WER: 9.52%
#
# Example 45:
#   Source:    ga_eueu_lll fa_ex_rrr wa_ii_hh ma_oo_hh sa_ex_rrr ga_eueu_rrr va_ee_rr ra_uu_hh ba_ex_yyy qa_uu_ng la_oo_rr fa_uu_rrr za_ee nga_pamaeh ra_eueu_lll da_rr
#   Target:    gleu fré wih moh sré greu ver ruh byé qung lor fru ze ng rleu dar
#   Predicted: gleu fré wih moh sré greu ver ruh byé qung lor fru ze ng rleu
#   CER: 6.00%, WER: 6.25%
#
# Example 46:
#   Source:    a_rr
#   Target:    ar
#   Predicted: ar
#   CER: 0.00%, WER: 0.00%
#
# Example 47:
#   Source:    pa_uu_rrr va_eueu_rr ta_ii_yyy za_oo_hh ra_yyy ga_uu_yyy fa_ee_rr qa_uu_ng ba_eueu_hh ba_oo_hh wa_eueu_rrr na_ii_yyy ca_oo_yyy nya_uu_hh ba_ex_ng nga_ii_ng nga_ii ya_ee_rrr ya_ex_yyy da_ee
#   Target:    pru veur tyi zoh rya gyu fer qung beuh boh wreu nyi cyo nyuh béng nging ngi yre yyé de
#   Predicted: pru veur tyi zoh rya gyu fer qung beuh boh wreu nyi cyo nyuh béng nging ngi yre yyé de
#   CER: 0.00%, WER: 0.00%
#
# Example 48:
#   Source:    ta_ee_ng na_ex_lll u sa_oo_rr
#   Target:    teng nlé u sor
#   Predicted: teng nlé u sor
#   CER: 0.00%, WER: 0.00%
#
# Example 49:
#   Source:    sa_oo_rr pa_pamaeh sa_ex_ng wa_ii ta_oo_lll wa_ii_rrr da_ex da_eueu ba_eueu_rrr
#   Target:    sor p séng wi tlo wri dé deu breu
#   Predicted: sor p séng jré tlo wri dé deu breu
#   CER: 12.00%, WER: 11.11%
#
# Example 50:
#   Source:    fa_ii_hh fa_ii_yyy da_ee_lll ba_pamaeh sya_oo_hh ca_pamaeh sa_ii_lll da_eueu_ng ga_eueu_lll
#   Target:    fih fyi dle b syoh c sli deung gleu
#   Predicted: fih fyi dle b syoh c qér deung gleu
#   CER: 11.11%, WER: 11.11%
#
# Example 51:
#   Predicted: dru bru c bye reng qing khah tér nér wyo dro khu koh yré ceung
#   CER: 14.29%, WER: 13.33%
#
# Example 57:
#   Source:    ra_ex_rr ga_eueu_yyy o_rr xa ta_oo_yyy ya_ii_hh nga_eueu_rr ma_eueu ba_pamaeh ka_uu_hh wa_ii va_ii_ng ya_eueu_ng qa_rrr wa_ee_yyy va_oo_rr pa_ii_yyy nga_ii_ng
#   Target:    rér gyeu or xa tyo yih ngeur meu b kuh wi ving yeung qra wye vor pyi nging
#   Predicted: rér heu or xa tyo yih ngeur meu fuh kuh wi ving lyu qra wye vor pyi nging
#   CER: 15.79%, WER: 16.67%
#
# Example 58:
#   Source:    sya_ii_rr ja_ii ta_yyy ta da_uu ca_rr la_uu_rrr la_uu_rr o_hh sya_eueu_rr wa_uu_lll ga_pamaeh
#   Target:    syir ji tya ta du car lru lur oh syeur wlu g
#   Predicted: syir ji tya ta du car lru lur oh syeur wlu g
#   CER: 0.00%, WER: 0.00%
#
# Example 59:
#   Source:    ya_ex_rrr za_uu_hh ka ca_ee_ng
#   Target:    yré zuh ka ceng
#   Predicted: yré zuh peuh
#   CER: 41.67%, WER: 50.00%
#
# Example 60:
#   Source:    va_ii sya_eueu_rr la_rrr za_eueu_hh ba_ee na_ex_rr ga_uu_lll na_ee_hh sya_ee_rr qa_oo_hh pa_oo_rrr la_pamaeh
#   Target:    vi syeur lra zeuh be nér glu neh syer qoh pro l
#   Predicted: vi syeur lra zeuh be nér glu neh syer qoh pro l
#   CER: 0.00%, WER: 0.00%
#
# Example 61:
#   Source:    la_eueu_ng ma_ee_ng ma_ii_rrr fa_ex_yyy wa_ii_lll ba_ee_lll ga_ii la_oo_yyy ya_uu_ng pa_eueu_ng fa_eueu_rr ca_eueu fa_yyy ya_ii_yyy wa_uu_lll ha_ee_rrr qa_ex_ng qa_rr ga ba_ii_lll da_eueu_rr nya nya_hh la_oo u_ng
#   Target:    leung meng mri fyé wli ble gi lyo yung peung feur ceu fya yyi wlu hre qéng qar ga bli deur nya nyah lo ung
#   Predicted: leung meng mri fyé wli ble gi lyo yung peung feur ceu fya yyi wlu hre qéng qar nyir bli ting lo kar lo
#   CER: 19.51%, WER: 20.00%
#
# Example 62:
#   Source:    fa_uu_hh ma_uu_hh va_ii_ng kha_ee_ng ya_ee_yyy ta_ii_yyy va_rrr nya_uu ya_yyy ya_lll za_hh ra_uu_yyy nya_pamaeh ta_oo_ng za_oo_ng wa_uu fa_ng ma_ex_rrr nya_uu_ng qa_pamaeh xa_ex sa_ex_hh wa_ex_ng za_uu_hh nya_ex_rr
#   Target:    fuh muh ving kheng yye tyi vra nyu yya yla zah ryu ny tong zong wu fang mré nyung q xé séh wéng zuh nyér
#   Predicted: fuh syu mra ding deung yu péh syoh qé kru xo ving roh wu syeu jli heu eh gor nye sre zeuh
#   CER: 77.50%, WER: 92.00%
#
# Example 63:
#   Source:    kha da_ee ra_oo_lll pa_oo_lll kha_uu ya_yyy da_uu_ng fa_ii_yyy
#   Target:    kha de rlo plo khu yya dung fyi
#   Predicted: kha de rlo plo khu yya dung fyi
#   CER: 0.00%, WER: 0.00%
#
# Example 64:
#   Source:    ga_ng
#   Target:    gang
#   Predicted: gang
#   CER: 0.00%, WER: 0.00%
#
# Example 65:
#   Source:    ja_ii_lll ca_ex_ng ka_oo za_yyy ta_eueu_lll wa_ee_rrr ta_oo_yyy nya_ex_ng
#   Target:    jli céng ko zya tleu wre tyo nyéng
#   Predicted: jli céng ko zya tleu wre tyo nyéng
#   CER: 0.00%, WER: 0.00%
#
# Example 66:
#   Source:    ba_ee_yyy ra_ex_hh ka_ee_ng sya_ee
#   Target:    bye réh keng sye
#   Predicted: bye cri keng 1
#   CER: 46.15%, WER: 50.00%
#
# Example 67:
#   Source:    ka_oo_lll ma_hh
#   Target:    klo mah
#   Predicted: klo mah
#   CER: 0.00%, WER: 0.00%
#
# Example 68:
#   Source:    ka_rrr
#   Target:    kra
#   Predicted: kra
#   CER: 0.00%, WER: 0.00%
#
# Example 69:
#   Source:    na_oo_hh na_ex_lll da_ee_yyy ka wa_eueu_hh za_eueu_rr ma_uu_yyy
#   Target:    noh nlé dye ka weuh zeur myu
#   Predicted: noh nlé dye ka weuh zeur myu
#   CER: 0.00%, WER: 0.00%
#
# Example 70:
#   Source:    va_eueu_rr i_hh sya_eueu ma_oo_hh ka_uu_yyy nga_ee fa_oo_yyy ga_yyy ka_uu_rrr ja_oo_hh ga_ex_rrr qa_lll
#   Target:    veur ih syeu moh kyu nge fyo gya kru joh gré qla
#   Predicted: veur ih syeu moh kyu xing fyo gya kru joh gré qla
#   CER: 8.11%, WER: 8.33%
#
# Example 71:
#   Source:    la_yyy ha_ex_yyy la_ee_lll da_pamaeh nga_uu_rr za_ng ta_pamaeh da_uu_ng ca_uu_hh la_uu_ng wa_lll ca_yyy ca_oo_lll ca_oo_rrr ja_ex_hh za_ex_hh sa_eueu_lll la_uu ba_uu_rrr va_oo_ng
#   Target:    lya hyé lle d ngur zang t dung cuh lung wla cya clo cro jéh zéh sleu lu bru vong
#   Predicted: lya hyé lle d séng zang t dung cuh lung wla cya clo cro jéh zéh sleu lu bru vong
#   CER: 6.56%, WER: 5.00%
#
# Example 72:
#   Source:    qa_eueu_hh
#   Target:    qeuh
#   Predicted: qeuh
#   CER: 0.00%, WER: 0.00%
#
# Example 73:
#   Source:    la_ee_lll la_ex_yyy ha_ex_yyy nya_eueu_ng wa_rrr la_oo_ng e_hh xa_pamaeh xa_ex_ng fa_ii_ng kha_oo qa_eueu_hh genep ha_oo ka_ii_rrr ma_uu_rrr nya_ex_rr kha_hh ga_ex_yyy ca_uu_lll ka_yyy
#   Target:    lle lyé hyé nyeung wra long eh x xéng fing kho qeuh 6 ho kri mru nyér khah gyé clu kya
#   Predicted: lle lyé hyé nyeung wra long eh x xéng qoh kho qeuh z ho kri mru nyér khah gyé clu kya
#   CER: 7.58%, WER: 9.52%
#
# Example 74:
#   Source:    fa_uu_rr
#   Target:    fur
#   Predicted: fur
#   CER: 0.00%, WER: 0.00%
#
# Example 75:
#   Source:    na_uu_yyy a_ng ja_uu_rr ka_ee_rrr wa_ii_lll nga_ii na_eueu_ng ca_ex_rr xa_ii_rr ha_uu_rrr qa_eueu tujuh
#   Target:    nyu ang jur kre wli ngi neung cér xir hru qeu 7
#   Predicted: nyu ang jur kre wli zeuh neung cér xir hru xih 7
#   CER: 19.44%, WER: 16.67%
#
# Example 76:
#   Source:    ha_eueu_rr ma_oo sa_ii_yyy ba_yyy ka_ii_ng pa_eueu_rr ma_ii_ng qa_ee_hh ha la_pamaeh ta_oo_yyy ma_ex_ng
#   Target:    heur mo syi bya king peur ming qeh ha l tyo méng
#   Predicted: heur mo syi bya king peur ming qeh ha l tyo méng
#   CER: 0.00%, WER: 0.00%
#
# Example 77:
#   Source:    ra_eueu_rrr
#   Target:    rreu
#   Predicted: rreu
#   CER: 0.00%, WER: 0.00%
#
# Example 78:
#   Source:    wa_ii_ng
#   Target:    wing
#   Predicted: wing
#   CER: 0.00%, WER: 0.00%
#
# Example 79:
#   Source:    dalapan ka_ex ka_eueu_lll ga_ii_yyy pa_eueu_yyy na_oo_lll i_ng la_oo_rrr ga_rrr wa_eueu_rr ra_ii_hh pa_ee_hh da_ex_ng za_ee_rr sa_ex_ng ma_ii_rr ka_ee_hh ma_oo_rr sya_rr ra_ng ha_ii_hh ya_ii_rr ca_oo_rr ta_ex_rrr na_ee_rr
#   Target:    8 ké kleu gyi pyeu nlo ing lro gra weur rih peh déng zer séng mir keh mor syar rang hih yir cor tré ner
#   Predicted: 8 ké kleu gyi pyeu nlo ing lro gra weur rih peh déng zer séng mir keh mor syar rang hih dra cor tré cang
#   CER: 8.86%, WER: 8.00%
#
# Example 80:
#   Source:    nga_oo_ng la_ee_rrr ja_ii ba_ex ra_eueu_lll sya_ee_hh da_ng kha_uu ra_oo ma_uu_rrr ya_oo
#   Target:    ngong lre ji bé rleu syeh dang khu ro mru yo
#   Predicted: ngong lre ji bé rleu syeh dang khu ro mru yo
#   CER: 0.00%, WER: 0.00%
#
# Example 81:
#   Source:    ka_yyy u
#   Target:    kya u
#   Predicted: kya u
#   CER: 0.00%, WER: 0.00%
#
# Example 82:
#   Source:    ja_oo_yyy
#   Target:    jyo
#   Predicted: jyo
#   CER: 0.00%, WER: 0.00%
#
# Example 83:
#   Source:    ta_eueu_hh ra_ee_rrr ja_ii_rr va_ee_rr pa_lll xa_ex xa_ex_hh na_ii_rrr ga_ex_rr ja_ee pa_eueu_ng ca_ee_ng sa_ee_rrr ba_lll nga_pamaeh kha na_oo_hh xa_uu fa_ii za_ii_ng ba_ee_rrr ca_eueu_hh ca_oo
#   Target:    teuh rre jir ver pla xé xéh nri gér je peung ceng sre bla ng kha noh xu fi zing bre ceuh co
#   Predicted: teuh rre meh ver pla xé xéh nri gér be peung ging sre bla ng kha noh xu fi zing bre ceuh co
#   CER: 8.70%, WER: 13.04%
#
# Example 84:
#   Source:    qa_ex ka_oo_rr va_ii_hh ta_eueu_ng ya_uu_yyy da_eueu_lll ca ba_lll ya_oo za_ex_ng pa_rrr ra_uu_ng ga_uu_rr
#   Target:    qé kor vih teung yyu dleu ca bla yo zéng pra rung gur
#   Predicted: qé rre meung teung yyu dleu ca bla yo zéng pra rung gur
#   CER: 19.51%, WER: 15.38%
#
# Example 85:
#   Source:    ra_uu_rrr va_uu ba_ex_rr ba ba_ex_yyy ra_eueu_hh wa_eueu_rrr ha_rr
#   Target:    rru vu bér ba byé reuh wreu har
#   Predicted: rru vu bér ba mle reuh wreu har
#   CER: 12.50%, WER: 12.50%
#
# Example 86:
#   Source:    ya_ee_rr ma_eueu_rr ra_eueu_ng ha_oo_yyy wa_eueu_hh wa_lll ja_ex_rrr na_uu_ng ga_pamaeh ba_oo dalapan
#   Target:    yer meur reung hyo weuh wla jré nung g bo 8
#   Predicted: yer jri reung hyo weuh wla jré nung g bo 8
#   CER: 12.12%, WER: 9.09%
#
# Example 87:
#   Source:    sa_hh za_rrr qa_eueu_ng sa_ex nga_pamaeh ka_eueu_lll wa_ee_lll nga_hh ca_oo na_yyy sa_ee_lll ja_eueu_ng na_eueu_yyy la_uu_rr ma_ee_rr ta_oo_rrr sa_rr ka_ee_rr ha_ex_hh ya_oo_rr fa_ii_rrr ha_ii sa_yyy ma_ii_hh
#   Target:    sah zra qeung sé ng kleu wle ngah co nya sle jeung nyeu lur mer tro sar ker héh yor fri hi sya mih
#   Predicted: sah zra sé sé ng kleu wle ngah co nya sle jeung nyeu lur k tro sar ker héh yor yyeu gi pér mih
#   CER: 21.33%, WER: 20.83%
#
# Example 88:
#   Source:    ka_ng xa_ii_rr ba_ee_lll ca_eueu da_eueu_ng ja_oo_lll kha_hh sya_eueu
#   Target:    kang xir ble ceu deung jlo khah syeu
#   Predicted: kang xir lang ceu deung jlo khah syeu
#   CER: 13.79%, WER: 12.50%
#
# Example 89:
#   Source:    nga_pamaeh na_uu_yyy ba_ee_yyy ya_rrr eu da_uu_hh qa_oo_hh ta_uu_hh
#   Target:    ng nyu bye yra eu duh qoh tuh
#   Predicted: ng ker bye yra eu 3 qoh tuh
#   CER: 27.27%, WER: 25.00%
#
# Example 90:
#   Source:    ka_uu_ng ra_eueu_ng qa_ee_hh ca_ii_rr qa_ee sa_yyy sya_ii_rr ja_uu_lll ma_pamaeh ha_uu_rr ja_ee_ng ca_oo_hh qa_ex qa_yyy ta_ee_rr qa_uu_rr va_oo_hh nga_ex_rr pa_hh
#   Target:    kung reung qeh cir qe sya syir jlu m hur jeng coh qé qya ter qur voh ngér pah
#   Predicted: kung reung qeh cir qe sya syir jlu m hur jeng coh qé qya ter qur yeng ngér pah
#   CER: 6.78%, WER: 5.26%
#
# Example 91:
#   Source:    ca_uu ca_ee_ng ta_ee_ng ga_uu_rr ka_ex_rr ca
#   Target:    cu ceng teng gur kér ca
#   Predicted: cu ceng teng gur kér ca
#   CER: 0.00%, WER: 0.00%
#
# Example 92:
#   Source:    ca_rrr ka_oo_rr da_ee qa_ii_rr ba_oo qa_ii_hh da_eueu_ng da_ii da_ex ba_eueu_rr na_eueu_rr ba_ee_yyy da_hh wa_ee sa_eueu za_lll na_oo_lll ka_ee_rr nya_uu nya_rr nga_hh pa_ex_ng
#   Target:    cra kor de qir bo qih deung di dé beur neur bye dah we seu zla nlo ker nyu nyar ngah péng
#   Predicted: cra kor de seu bo qih deung di dé beur neur bye dah we seu zla nlo ker nyu péng ngah péng
#   CER: 10.29%, WER: 9.09%
#
# Example 93:
#   Source:    ga_ex_lll ma_ex_hh pa_ee_lll ta_uu ba_uu_yyy wa_ex_lll ba_ee_lll ba_uu_hh fa_oo_rrr ca_eueu_ng va_ee za_uu_hh ra xa_ex_ng za_eueu_ng pa_eueu_hh va_lll ya_uu_hh da_eueu_hh ha_ex_rrr fa_ee_hh ga_ii_hh nya_eueu_ng
#   Target:    glé méh ple tu byu wlé ble buh fro ceung ve zuh ra xéng zeung peuh vla yuh deuh hré feh gih nyeung
#   Predicted: glé méh ple tu byu wlé ble buh fro ceung ve zuh ra xéng zeung peuh vla ru deuh hré ger gih nyeung
#   CER: 5.26%, WER: 8.70%
#
# Example 94:
#   Source:    ha_ee_lll
#   Target:    hle
#   Predicted: hle
#   CER: 0.00%, WER: 0.00%
#
# Example 95:
#   Source:    da_eueu_rr ga_ng pa_eueu_rrr ma_ex_rrr va_ii_hh ba_oo_lll la_rr na_pamaeh ha_uu_rrr
#   Target:    deur gang preu mré vih blo lar n hru
#   Predicted: deur gang preu mré vih blo lar n hru
#   CER: 0.00%, WER: 0.00%
#
# Example 96:
#   Source:    ra_uu_hh kha_ee_ng na_rrr wa_ex_lll pa_rr ta_ex_ng ga_oo_hh ba_pamaeh sya_ee pa da_ex_rr fa_oo_lll na_oo_lll xa_rrr xa_uu va_ee_rr nya_eueu_hh va_rr
#   Target:    ruh kheng nra wlé par téng goh b sye pa dér flo nlo xra xu ver nyeuh var
#   Predicted: ruh kheng nra wlé par téng goh b sye pa dér nye nlo xra xu ver nyeuh var
#   CER: 5.45%, WER: 5.56%
#
# Example 97:
#   Source:    ya_ee_rrr ta_ee_ng ha ka_uu_yyy ta_ex_rr ma_ex_hh
#   Target:    yre teng ha kyu tér méh
#   Predicted: yre teng kh kyu tér méh
#   CER: 11.11%, WER: 16.67%
#
# Example 98:
#   Source:    qa_uu_rr na_eueu_ng
#   Target:    qur neung
#   Predicted: qur neung
#   CER: 0.00%, WER: 0.00%
#
# Example 99:
#   Source:    ta_oo_rrr xa_eueu e ja_yyy nya_rr ta_ee_rrr ka_ex_lll ja_ex sa_ex_hh ma_oo_lll da_eueu ga_eueu_rrr ya_ee_rr
#   Target:    tro xeu e jya nyar tre klé jé séh mlo deu greu yer
#   Predicted: tro nyeung e jya nyar tre klé jé séh mlo deu greu yer greu
#   CER: 21.05%, WER: 15.38%
#
# Example 100:
#   Source:    da_yyy ha_rrr ga_uu_hh ga_yyy na_ee_ng
#   Target:    dya hra guh gya neng
#   Predicted: dya hra guh gya neng
#   CER: 0.00%, WER: 0.00%
#
# Evaluation from checkpoint at epoch 243:
#   CER: 6.79%
#   WER: 6.80%
