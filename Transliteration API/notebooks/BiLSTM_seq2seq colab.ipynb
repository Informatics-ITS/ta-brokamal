base_target_tokens = [
    'target',
    'nga', 'nge', 'ngu', 'ngi', 'ngé', 'ngo', 'ngeu', 'ng',
    'ngah', 'ngang', 'ngar',
    'ngeh', 'ngeng', 'nger',
    'nguh', 'ngung', 'ngur',
    'ngih', 'nging', 'ngir',
    'ngéh', 'ngéng', 'ngér',
    'ngoh', 'ngong', 'ngor',
    'ngeuh', 'ngeung', 'ngeur',
    'a', 'i', 'u', 'e', 'o', 'eu', 'é', 'ang', 'ah', 'ar',
    'ing', 'ih', 'ir',
          'ung', 'uh', 'ur',
          'eng', 'eh', 'er',
          'ong', 'oh', 'or', '1', '2', '3', '4', '5', '6', '7', '8', '9', '0', 'ka', 'na', 'pa', 'ma', 'ta', 'da', 'ba', 'ga', 'ja', 'ra', 'la', 'sa', 'ya', 'wa', 'ha', 'za', 'xa', 'fa', 'va', 'ca', 'nya', 'kha', 'sya', 'qa', 'kang', 'kar', 'kah', 'nang', 'nar', 'nah', 'pang', 'par', 'pah', 'mang', 'mar', 'mah', 'tang', 'tar', 'tah', 'dang', 'dar', 'dah', 'bang', 'bar', 'bah', 'gang', 'gar', 'gah', 'jang', 'jar', 'jah', 'rang', 'rar', 'rah', 'lang', 'lar', 'lah', 'sang', 'sar', 'sah', 'yang', 'yar', 'yah', 'wang', 'war', 'wah', 'hang', 'har', 'hah', 'zang', 'zar', 'zah', 'xang', 'xar', 'xah', 'fang', 'far', 'fah', 'vang', 'var', 'vah', 'cang', 'car', 'cah', 'nyang', 'nyar', 'nyah', 'khang', 'khar', 'khah', 'syang', 'syar', 'syah', 'qang', 'qar', 'qah', 'kra', 'kla', 'kya', 'nra', 'nla', 'nya', 'pra', 'pla', 'pya', 'mra', 'mla', 'mya', 'tra', 'tla', 'tya', 'dra', 'dla', 'dya', 'bra', 'bla', 'bya', 'gra', 'gla', 'gya', 'jra', 'jla', 'jya', 'rra', 'rla', 'rya', 'lra', 'lla', 'lya', 'sra', 'sla', 'sya', 'yra', 'yla', 'yya', 'wra', 'wla', 'wya', 'hra', 'hla', 'hya', 'zra', 'zla', 'zya', 'xra', 'xla', 'xya', 'fra', 'fla', 'fya', 'vra', 'vla', 'vya', 'cra', 'cla', 'cya', 'qra', 'qla', 'qya', 'ké', 'ki', 'ko', 'ku', 'ke', 'keu', 'k', 'né', 'ni', 'no', 'nu', 'ne', 'neu', 'n', 'pé', 'pi', 'po', 'pu', 'pe', 'peu', 'p', 'mé', 'mi', 'mo', 'mu', 'me', 'meu', 'm', 'té', 'ti', 'to', 'tu', 'te', 'teu', 't', 'dé', 'di', 'do', 'du', 'de', 'deu', 'd', 'bé', 'bi', 'bo', 'bu', 'be', 'beu', 'b', 'gé', 'gi', 'go', 'gu', 'ge', 'geu', 
re', 'mle', 'mye', 'mreu', 'mleu', 'myeu', 'tré', 'tlé', 'tyé', 'tri', 'tli', 'tyi', 'tro', 'tlo', 'tyo', 'tru', 'tlu', 'tyu', 'tre', 'tle', 'tye', 'treu', 'tleu', 'tyeu', 'dré', 'dlé', 'dyé', 'dri', 'dli', 'dyi', 'dro', 'dlo', 'dyo', 'dru', 'dlu', 'dyu', 'dre', 'dle', 'dye', 'dreu', 'dleu', 'dyeu', 'bré', 'blé', 'byé', 'bri', 'bli', 'byi', 'bro', 'blo', 'byo', 'bru', 'blu', 'byu', 'bre', 'ble', 'bye', 'breu', 'bleu', 'byeu', 'gré', 'glé', 'gyé', 'gri', 'gli', 'gyi', 'gro', 'glo', 'gyo', 'gru', 'glu', 'gyu', 'gre', 'gle', 'gye', 'greu', 'gleu', 'gyeu', 'jré', 'jlé', 'jyé', 'jri', 'jli', 'jyi', 'jro', 'jlo', 'jyo', 'jru', 'jlu', 'jyu', 'jre', 'jle', 'jye', 'rri', 'rli', 'ryi', 'rro', 'rlo', 'ryo', 'rru', 'rlu', 'ryu', 'rre', 'rle', 'rye', 'rreu', 'rleu', 'ryeu', 'lré', 'llé', 'lyé', 'lri', 'lli', 'lyi', 'lro', 'llo', 'lyo', 'lru', 'llu', 'lyu', 'lre', 'lle', 'lye', 'sré', 'slé', 'syé', 'sri', 'sli', 'syi', 'sro', 'slo', 'syo', 'sru', 'slu', 'syu', 'sre', 'sle', 'sye', 'sreu', 'sleu', 'syeu', 'yré', 'ylé', 'yyé', 'yri', 'yli', 'yyi', 'yro', 'ylo', 'yyo', 'yru', 'ylu', 'yyu', 'yre', 'yle', 'yye', 'yreu', 'yleu', 'yyeu', 'wré', 'wlé', 'wyé', 'wri', 'wli', 'wyi', 'wro', 'wlo', 'wyo', 'wru', 'wlu', 'wyu', 'wre', 'wle', 'wye', 'wreu', 'wleu', 'wyeu', 'hré', 'hlé', 'hyé', 'hri', 'hli', 'hyi', 'hro', 'hlo', 'hyo', 'hru', 'hlu', 'hyu', 'hre', 'hle', 'hye', 'hreu', 'hleu', 'hyeu', 'fré', 'flé', 'fyé', 'fri', 'fli', 'fyi', 'fro', 'flo', 'fyo', 'fru', 'flu', 'fre', 'fle', 'cri', 'cli', 'cyi', 'cro', 'clo', 'cyo', 'cru', 'clu', 'cyu']

# dataset generation
filename = "dataset.csv"
with open(filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["source", "target"])

    total_rrows = 0
    target_rrows = 10000

    # First ensure every token is used at least once
    for src_token in base_source_tokens:
        tgt_token = base_target_tokens[base_source_tokens.index(src_token)]
        writer.writerow([src_token.lower(), tgt_token.lower()])
        total_rrows += 1

    # Then fill remaining rows with random combinations
    while total_rrows < target_rrows:
        length = random.randint(1, 25)
        src_tokens = random.sample(base_source_tokens, k=length)
        tgt_tokens = [
            base_target_tokens[base_source_tokens.index(w)] if w in base_source_tokens else w
            for w in src_tokens
        ]
        writer.writerow([" ".join(src_tokens).lower(), " ".join(tgt_tokens).lower()])
        total_rrows += 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.model_selection import train_test_split

# 1. Data Preparation
df = pd.read_csv("dataset.csv")

# Split into train and test sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

def build_vocab(tokens):
    vocab = {tok: i+4 for i, tok in enumerate(tokens)}
    vocab["<pad>"] = 0
    vocab["<sos>"] = 1
    vocab["<eos>"] = 2
    vocab["<unk>"] = 3
    return vocab

source_tokens = [t.lower() for t in df['source'].str.split().explode().unique()]
target_tokens = [t.lower() for t in df['target'].str.split().explode().unique()]
SRC_VOCAB = build_vocab(source_tokens)
TGT_VOCAB = build_vocab(target_tokens)
SRC_IVOCAB = {i: t for t, i in SRC_VOCAB.items()}
TGT_IVOCAB = {i: t for t, i in TGT_VOCAB.items()}

def encode(tokens, vocab):
    return [vocab.get(tok, vocab["<unk>"]) for tok in tokens]

class Seq2SeqDataset(Dataset):
    def __init__(self, df, src_vocab, tgt_vocab):
        self.pairs = []
        for _, row in df.iterrows():
            src = encode(row['source'].split(), src_vocab)
            tgt = [tgt_vocab["<sos>"]] + encode(row['target'].split(), tgt_vocab) + [tgt_vocab["<eos>"]]
            self.pairs.append((src, tgt))
    def __len__(self): return len(self.pairs)
    def __getitem__(self, idx): return self.pairs[idx]

def collate_fn(batch):
    srcs, tgts = zip(*batch)
    src_lens = [len(s) for s in srcs]
    tgt_lens = [len(t) for t in tgts]
    src_pad = torch.zeros(len(srcs), max(src_lens), dtype=torch.long)
    tgt_pad = torch.zeros(len(tgts), max(tgt_lens), dtype=torch.long)
    for i, (s, t) in enumerate(zip(srcs, tgts)):
        src_pad[i, :len(s)] = torch.tensor(s)
        tgt_pad[i, :len(t)] = torch.tensor(t)
    return src_pad, tgt_pad, src_lens, tgt_lens

# Use train_df and test_df to create datasets and loaders
train_dataset = Seq2SeqDataset(train_df, SRC_VOCAB, TGT_VOCAB)
test_dataset = Seq2SeqDataset(test_df, SRC_VOCAB, TGT_VOCAB)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)

# %%
# 2. Model Definition
class Encoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hid_dim, n_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim, padding_idx=SRC_VOCAB["<pad>"])
        self.lstm = nn.LSTM(emb_dim, hid_dim, n_layers, bidirectional=True, batch_first=True)
    def forward(self, src, src_lens):
        emb = self.embedding(src)
        packed = nn.utils.rnn.pack_padded_sequence(emb, src_lens, batch_first=True, enforce_sorted=False)
        outputs, (h, c) = self.lstm(packed)
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs, batch_first=True)
        return outputs, (h, c)

class BahdanauAttention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        self.attn = nn.Linear(enc_hid_dim * 2 + dec_hid_dim, dec_hid_dim)
        self.v = nn.Parameter(torch.rand(dec_hid_dim))
    def forward(self, hidden, encoder_outputs, mask):
        src_len = encoder_outputs.size(1)
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim=2)))
        energy = energy @ self.v
        energy = energy.masked_fill(mask == 0, -1e10)
        return F.softmax(energy, dim=1)

class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, enc_hid_dim, dec_hid_dim, attention, n_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim, padding_idx=TGT_VOCAB["<pad>"])
        self.lstm = nn.LSTM(emb_dim + enc_hid_dim*2, dec_hid_dim, n_layers, batch_first=True)
        self.fc_out = nn.Linear(dec_hid_dim + enc_hid_dim*2 + emb_dim, vocab_size)
        self.attention = attention
    def forward(self, input, hidden, cell, encoder_outputs, mask):
        input = input.unsqueeze(1)
        emb = self.embedding(input)
        attn_weights = self.attention(hidden[-1], encoder_outputs, mask)
        attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)
        lstm_input = torch.cat((emb, attn_applied), dim=2)
        output, (hidden, cell) = self.lstm(lstm_input, (hidden, cell))
        output = output.squeeze(1)
        attn_applied = attn_applied.squeeze(1)
        emb = emb.squeeze(1)
        pred = self.fc_out(torch.cat((output, attn_applied, emb), dim=1))
        return pred, hidden, cell, attn_weights

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, src_pad_idx, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.device = device
        self.fc_hidden = nn.Linear(encoder.lstm.hidden_size * 2, decoder.lstm.hidden_size)
        self.fc_cell = nn.Linear(encoder.lstm.hidden_size * 2, decoder.lstm.hidden_size)
    def create_mask(self, src):
        return (src != self.src_pad_idx)
    def forward(self, src, src_lens, tgt, teacher_forcing_ratio=0.5):
        batch_size, tgt_len = tgt.shape
        outputs = torch.zeros(batch_size, tgt_len, self.decoder.embedding.num_embeddings).to(self.device)
        encoder_outputs, (h, c) = self.encoder(src, src_lens)
        h_cat = torch.cat((h[-2,:,:], h[-1,:,:]), dim=1)
        c_cat = torch.cat((c[-2,:,:], c[-1,:,:]), dim=1)
        h_dec = torch.tanh(self.fc_hidden(h_cat)).unsqueeze(0)
        c_dec = torch.tanh(self.fc_cell(c_cat)).unsqueeze(0)
        input = tgt[:,0]
        mask = self.create_mask(src)
        for t in range(1, tgt_len):
            output, h_dec, c_dec, _ = self.decoder(input, h_dec, c_dec, encoder_outputs, mask)
            outputs[:,t] = output
            teacher_force = torch.rand(1).item() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = tgt[:,t] if teacher_force else top1
        return outputs

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
INPUT_DIM = len(SRC_VOCAB)
OUTPUT_DIM = len(TGT_VOCAB)
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
HID_DIM = 256

attn = BahdanauAttention(HID_DIM, HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, HID_DIM, attn)
model = Seq2Seq(enc, dec, SRC_VOCAB["<pad>"], device).to(device)

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index=TGT_VOCAB["<pad>"])

def levenshtein(ref, hyp):
    m, n = len(ref), len(hyp)
    dp = np.zeros((m + 1, n + 1), dtype=int)
    for i in range(m + 1):
        dp[i][0] = i
    for j in range(n + 1):
        dp[0][j] = j
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if ref[i - 1] == hyp[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = 1 + min(dp[i - 1][j], dp[i][j - 1], dp[i - 1][j - 1])
    return dp[m][n]

# Metric evaluation functions

def compute_cer(ref, hyp):
    ref = ref.replace(' ', '')
    hyp = hyp.replace(' ', '')
    if len(ref) == 0:
        return 0.0 if len(hyp) == 0 else 1.0
    return levenshtein(ref, hyp) / len(ref)

def compute_wer(ref, hyp):
    ref_words = ref.split()
    hyp_words = hyp.split()
    if len(ref_words) == 0:
        return 0.0 if len(hyp_words) == 0 else 1.0
    return levenshtein(ref_words, hyp_words) / len(ref_words)
# Use train_loader for training
best_loss = float('inf')
best_model_state = None

for epoch in range(150):
    model.train()
    total_loss = 0
    batch_losses = []
    for src, tgt, src_lens, tgt_lens in train_loader:
        src, tgt = src.to(device), tgt.to(device)
        optimizer.zero_grad()
        output = model(src, src_lens, tgt)
        output_dim = output.shape[-1]
        output = output[:,1:].reshape(-1, output_dim)
        tgt = tgt[:,1:].reshape(-1)
        loss = criterion(output, tgt)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        batch_losses.append(loss.item())
    avg_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")
    # Save the model if it has the lowest loss so far
    if avg_loss < best_loss:
        best_loss = avg_loss
        best_model_state = model.state_dict()

# After training, load the best model
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    print(f"Loaded best model with loss: {best_loss:.4f}")
# Out:
# Epoch 1, Loss: 6.2663
# Epoch 2, Loss: 3.3058
# Epoch 3, Loss: 1.2038
# Epoch 4, Loss: 0.7618
# Epoch 5, Loss: 0.5448
# Epoch 6, Loss: 0.4886
# Epoch 7, Loss: 0.2888
# Epoch 8, Loss: 0.1910
# Epoch 9, Loss: 0.1012
# Epoch 10, Loss: 0.0996
# Epoch 11, Loss: 0.0517
# Epoch 12, Loss: 0.0434
# Epoch 13, Loss: 0.0505
# Epoch 14, Loss: 1.3130
# Epoch 15, Loss: 0.2586
# Epoch 16, Loss: 0.1121
# Epoch 17, Loss: 0.0912
# Epoch 18, Loss: 0.4213
# Epoch 19, Loss: 0.1036
# Epoch 20, Loss: 0.0330
# Epoch 21, Loss: 0.0208
# Epoch 22, Loss: 0.0156
# Epoch 23, Loss: 0.0253
# Epoch 24, Loss: 0.0249
# Epoch 25, Loss: 0.0283
# Epoch 26, Loss: 0.0353
# Epoch 27, Loss: 0.0287
# Epoch 28, Loss: 0.0170
# Epoch 29, Loss: 0.1481
# Epoch 30, Loss: 0.1195
# Epoch 31, Loss: 0.3367
# Epoch 32, Loss: 0.3488
# Epoch 118, Loss: 0.0000
# Epoch 119, Loss: 0.0000
# Epoch 120, Loss: 0.0000
# Epoch 121, Loss: 0.0000
# Epoch 122, Loss: 0.0000
# Epoch 123, Loss: 0.0000
# Epoch 124, Loss: 0.0000
# Epoch 125, Loss: 0.0000
# Epoch 126, Loss: 0.0000
# Epoch 127, Loss: 0.0000
# Epoch 128, Loss: 0.0000
# Epoch 129, Loss: 0.0000
# Epoch 130, Loss: 0.0000
# Epoch 131, Loss: 0.0000
# Epoch 132, Loss: 0.0001
# Epoch 133, Loss: 0.1977
# Epoch 134, Loss: 0.2071
# Epoch 135, Loss: 0.0309
# Epoch 136, Loss: 0.0213
# Epoch 137, Loss: 0.0118
# Epoch 138, Loss: 0.0094
# Epoch 139, Loss: 0.0060
# Epoch 140, Loss: 0.0011
# Epoch 141, Loss: 0.0007
# Epoch 142, Loss: 0.0005
# Epoch 143, Loss: 0.0004
# Epoch 144, Loss: 0.0004
# Epoch 145, Loss: 0.0003
# Epoch 146, Loss: 0.0003
# Epoch 147, Loss: 0.0002
# Epoch 148, Loss: 0.0002
# Epoch 149, Loss: 0.0002
# Epoch 150, Loss: 0.0002
# Loaded best model with loss: 0.0000

# %%
def translate(model, src_sentence, max_len=30):
    model.eval()
    src_tokens = encode(src_sentence.lower().split(), SRC_VOCAB)
    src_tensor = torch.tensor(src_tokens).unsqueeze(0).to(device)
    src_lens = [len(src_tokens)]
    with torch.no_grad():
        encoder_outputs, (h, c) = model.encoder(src_tensor, src_lens)
        h_cat = torch.cat((h[-2,:,:], h[-1,:,:]), dim=1)
        c_cat = torch.cat((c[-2,:,:], c[-1,:,:]), dim=1)
        h_dec = torch.tanh(model.fc_hidden(h_cat)).unsqueeze(0)
        c_dec = torch.tanh(model.fc_cell(c_cat)).unsqueeze(0)
        input = torch.tensor([TGT_VOCAB["<sos>"]]).to(device)
        mask = model.create_mask(src_tensor)
        result = []
        for _ in range(max_len):
            output, h_dec, c_dec, _ = model.decoder(input, h_dec, c_dec, encoder_outputs, mask)
            top1 = output.argmax(1)
            if top1.item() == TGT_VOCAB["<eos>"]:
                break
            result.append(TGT_IVOCAB[top1.item()])
            input = top1
    return " ".join(result)

# Example usage:
print(translate(model, "ka na pa_hh ka_lll ka_yyy ka_rrr ka_rr nga_uu"))
# Out:
# ka na pah kla kya kra kar ngu

# %%
    model.eval()
    total_cer = 0
    total_wer = 0
    n_samples = 0
    with torch.no_grad():
        example_printed = 0
        for src, tgt, src_lens, tgt_lens in test_loader:
            src = src.to(device)
            for i in range(src.size(0)):
                src_sentence = ' '.join([SRC_IVOCAB[idx.item()] for idx in src[i] if idx.item() != SRC_VOCAB["<pad>"]])
                tgt_sentence = ' '.join([TGT_IVOCAB[idx.item()] for idx in tgt[i] if idx.item() not in [TGT_VOCAB["<pad>"], TGT_VOCAB["<sos>"], TGT_VOCAB["<eos>"]]])
                pred_sentence = translate(model, src_sentence)
                cer = compute_cer(tgt_sentence, pred_sentence)
                wer = compute_wer(tgt_sentence, pred_sentence)
                total_cer += cer
                total_wer += wer
                n_samples += 1
                # Print a few examples
                if example_printed < 100:
                    print(f"Example {example_printed+1}:")
                    print(f"  Source:    {src_sentence}")
                    print(f"  Target:    {tgt_sentence}")
                    print(f"  Predicted: {pred_sentence}")
                    print(f"  CER: {cer:.2%}, WER: {wer:.2%}\n")
                    example_printed += 1
    print(f"CER: {total_cer/n_samples:.2%}, WER: {total_wer/n_samples:.2%}")
# Out:
# Example 1:
#   Source:    qa_lll ma_uu_rr e_ng qa_eueu_rr sya pa_eueu ta_ex ca_ee ka_ng ba_ee_ng za_eueu_hh
#   Target:    qla mur eng qeur sya peu té ce kang beng zeuh
#   Predicted: qla mur eng qeur sya peu té ce kang beng zeuh
#   CER: 0.00%, WER: 0.00%
#
# Example 2:
#   Source:    i_ng la_pamaeh sa_hh za_oo_hh wa_eueu_rr wa_eueu_lll ja_eueu_hh da_ex_rr
#   Target:    ing l sah zoh weur wleu jeuh dér
#   Predicted: ing l sah zoh weur wleu jeuh dér
#   CER: 0.00%, WER: 0.00%
#
# Example 3:
#   Source:    ya_uu_yyy ka_ex ma_oo_yyy ba_ex la_eueu_hh ra_yyy na_ee_rr fa_ex_lll da_ee_rrr ya_ee wa_ng ta_eueu_ng wa_eueu_yyy pa_ex_rrr
#   Target:    yyu ké myo bé leuh rya ner flé dre ye wang teung wyeu pré
#   Predicted: yyu ké myo bé leuh rya ner flé dre ye wang teung wyeu pré
#   CER: 0.00%, WER: 0.00%
#
# Example 4:
#   Source:    ca_uu_rrr sya_eueu_ng wa_oo ka_oo_rrr ya_ii_lll wa_rrr
#   Target:    cru syeung wo kro yli wra
#   Predicted: cru syeung wo kro yli wra
#   CER: 0.00%, WER: 0.00%
#
# Example 5:
#   Source:    nga ca_oo_rrr ra_rr ka_ex ra_ii_hh ma_lll wa_ee_hh ya_ex_rr fa_ii_rrr sa_ee_hh ma_hh na_oo_hh pa_uu_hh na_ex sya_ng ya_oo_rr ka_ee_hh nya_uu_rr ta_eueu_lll na_oo_rr ha_ex_yyy ma_ee
#   Target:    nga cro rar ké rih mla weh yér fri seh mah noh puh né syang yor keh nyur tleu nor hyé me
#   Predicted: nga cro rar ké rih mla weh yér fri seh mah noh puh né syang yor keh nyur tleu nor hyé me
#   CER: 0.00%, WER: 0.00%
#
# Example 6:
#   Source:    ca_ii_rr va_ee nya_oo_rr tilu za_uu_ng ga_eueu_hh qa_ii_ng ja_eueu_hh na_ee_rr ma_ex_hh o_ng ra_uu_rr ta_ee_yyy
#   Target:    cir ve nyor 3 zung geuh qing jeuh ner méh ong rur tye
#   Predicted: cir ve nyor 3 zung geuh qing jeuh ner méh ong rur tye
#   CER: 0.00%, WER: 0.00%
#
# Example 7:
#   Source:    la_oo_rr
#   Target:    lor
#   Predicted: lor
#   CER: 0.00%, WER: 0.00%
#
# Example 8:
#   Source:    za_ee pa_ii_rr fa_yyy sya_uu_ng ha_ii_yyy ya_eueu_ng ta_ex_lll ka_ee_hh sa_ii va_rr ca_eueu_ng nga_ex fa_ex_hh ba_ii_yyy ma_uu_ng qa_ee pa_ii_ng
#   Target:    ze pir fya syung hyi yeung tlé keh si var ceung ngé féh byi mung qe ping
#   Predicted: ze pir fya syung hyi yeung tlé keh si var ceung ngé féh byi mung qe ping
#   CER: 0.00%, WER: 0.00%
#
# Example 9:
#   Source:    la_ex_ng a_rr da_pamaeh sa_uu_rrr za_ex_ng
#   Target:    léng ar d sru zéng
#   Predicted: léng ar d sru zéng
#   CER: 0.00%, WER: 0.00%
#
# Example 10:
#   Source:    pa_ee_hh
#   Target:    peh
#   Predicted: peh
#   CER: 0.00%, WER: 0.00%
#
# Example 11:
#   Source:    wa_ee_lll ta_ee_lll qa_ii_hh ga_ex_ng ma_ex_rr ja_rrr ja_uu_hh wa_rr na_oo_rrr nga_ii_hh wa_uu la_ex_yyy na_ex_yyy nya_oo_ng ta_uu_lll ta_ee_ng ma_oo va_ee_ng ja_lll fa sa_oo_lll xa_ex_hh da_uu_hh sya_ex qa_ee_rr
#   Target:    wle tle qih géng mér jra juh war nro ngih wu lyé nyé nyong tlu teng mo veng jla fa slo xéh duh syé qer
#   Predicted: wle tle qih géng mér jra juh war nro ngih wu lyé nyé nyong tlu teng mo veng jla fa slo xéh duh syé qer
#   CER: 0.00%, WER: 0.00%
#
# Example 12:
#   Source:    ya_eueu_lll pa_rr na_ee_rrr ra_oo_ng ta_uu_lll la_uu_ng ca_eueu_rr ta_rr ba_pamaeh fa_rr ba_uu_lll ja_ii pa_ii_hh ra_rr ka_ee_hh ta_oo_ng za_ee qa_oo_rr ca_oo_lll ga_ee_hh
#   Target:    yleu par nre rong tlu lung ceur tar b far blu ji pih rar keh tong ze qor clo geh
#   Predicted: yleu par nre rong tlu lung ceur tar b far blu ji pih rar keh tong ze qor clo geh
#   CER: 0.00%, WER: 0.00%
#
# Example 13:
#   Source:    a_rr ga_oo_hh na_eueu u_rr da_hh ta la_ee_ng ca_yyy nya_uu_ng sa_oo_lll ha_oo_lll da_ii_rr u_ng va_ii_rr ha_ii_yyy za_rrr
#   Target:    ar goh neu ur dah ta leng cya nyung slo hlo dir ung vir hyi zra
#   Predicted: ar goh neu ur dah ta leng cya nyung slo hlo dir ung vir hyi zra
#   CER: 0.00%, WER: 0.00%
#
# Example 14:
#   Source:    kha_oo sa_ex_hh ma_ii_rrr ra_ii_ng ma_oo_lll na_eueu_ng wa_oo_hh ta_ng ba_oo_lll ma_ii sa_lll da_uu_ng nga_ii_rr ba_eueu_hh wa_eueu_ng
#   Target:    kho séh mri ring mlo neung woh tang blo mi sla dung ngir beuh weung
#   Predicted: kho séh mri ring mlo neung woh tang blo mi sla dung ngir beuh weung
#   CER: 0.00%, WER: 0.00%
#
# Example 15:
#   Source:    nya_ee ra_ex_ng wa_ii_ng ba_ex_rr la_oo_lll da_eueu_lll sya_oo_hh sa_hh sya_uu_rr da_uu_lll qa_ex ba_hh ca_ng nga_ex_ng na_uu_rrr ta_oo_ng ja_oo_hh
#   Target:    nye réng wing bér llo dleu syoh sah syur dlu qé bah cang ngéng nru tong joh
#   CER: 0.00%, WER: 0.00%
#
# Example 30:
#   Source:    kha_rr sya_oo_ng nga_oo za_uu_hh ga_rrr
#   Target:    khar syong ngo zuh gra
#   Predicted: khar syong ngo zuh gra
#   CER: 0.00%, WER: 0.00%
#
# Example 31:
#   Source:    ha_oo
#   Target:    ho
#   Predicted: ho
#   CER: 0.00%, WER: 0.00%
#
# Example 32:
#   Source:    wa_ee_rrr ga_ee_rrr ya_ii_ng ma_ex_hh ma_uu_rrr ra_oo_ng ca_ex_hh na_yyy ja_rrr ba_eueu_rrr da_ee_ng nga_hh qa_pamaeh na_rr ha_eueu_rrr ga_oo_rr ja_ee_rr na_eueu_rr nya_uu_ng fa_ii_rr fa_ex_yyy xa_ex e
#   Target:    wre gre ying méh mru rong céh nya jra breu deng ngah q nar hreu gor jer neur nyung fir fyé xé e
#   Predicted: wre gre ying méh mru rong céh nya jra breu deng ngah q nar hreu gor jer neur nyung fir fyé xé e
#   CER: 0.00%, WER: 0.00%
#
# Example 33:
#   Source:    ma_uu ta_ee pa_oo_rr
#   Target:    mu te por
#   Predicted: mu te por
#   CER: 0.00%, WER: 0.00%
#
# Example 34:
#   Source:    na_ex_rr sa_ex_yyy va_oo_rr sa_ex_lll za_ii_rr pa_hh ga_eueu va_ee_hh pa_ee ma_ex_lll pa_oo_lll ha_ee_lll
#   Target:    nér syé vor slé zir pah geu veh pe mlé plo hle
#   Predicted: nér syé vor slé zir pah geu veh pe mlé plo hle
#   CER: 0.00%, WER: 0.00%
#
# Example 35:
#   Source:    xa_ex_ng qa_oo_hh ta_ee_yyy ma_pamaeh sa_eueu_rrr e ra_oo_hh ka_oo_yyy xa_ii_ng i_rr ra_ii ra_hh la_ex_yyy fa_oo_ng ca_uu_hh
#   Target:    xéng qoh tye m sreu e roh kyo xing ir ri rah lyé fong cuh
#   Predicted: xéng qoh tye m sreu e roh kyo xing ir ri rah lyé fong cuh
#   CER: 0.00%, WER: 0.00%
#
# Example 36:
#   Source:    pa_ex_yyy ba_uu_ng ta_rr nya_ii_rr nya_ex_rr nya_oo ba_ee_rrr na_uu_lll ha_eueu_yyy xa_ii_hh xa_ex_rr va_ee_hh ra_ex_hh ya_uu_yyy ja_oo_yyy e_ng pa_ex_lll nya_ii la_ii_rr kha_uu ja_oo_rr
#   Target:    pyé bung tar nyir nyér nyo bre nlu hyeu xih xér veh réh yyu jyo eng plé nyi lir khu jor
#   Predicted: pyé bung tar nyir nyér nyo bre nlu hyeu xih xér veh réh yyu jyo eng plé nyi lir khu jor
#   CER: 0.00%, WER: 0.00%
#
# Example 37:
#   Source:    nga_ex_hh za_eueu_rr ga_ex_hh pa_ii_ng sa_ex_rrr pa_ee_rrr da_ee fa_eueu_ng ha_ee_ng da_ex_rrr ja_ex pa_eueu_lll za_ee la_ii_lll pa_ee_hh ja_uu_rr ha_oo_lll a_ng wa_oo_yyy ra_ii_rr
#   Target:    ngéh zeur géh ping sré pre de feung heng dré jé pleu ze lli peh jur hlo ang wyo rir
#   Predicted: ngéh zeur géh ping sré pre de feung heng dré jé pleu ze lli peh jur hlo ang wyo rir
#   CER: 0.00%, WER: 0.00%
#
# Example 38:
#   Source:    ta_oo
#   Target:    to
#   Predicted: to
#   CER: 0.00%, WER: 0.00%
#
# Example 39:
#   Source:    da_ng sa_ee_lll fa_ee_ng ba_eueu_rrr ha_ee_lll da_yyy ga_ee_rrr da_ee_lll ma_ee_hh fa_ex_yyy wa_uu_hh ba_oo_ng ca_uu_rr ca_eueu_hh na_oo_hh ka_ex_yyy sa_oo_rr va_rr ha_rr na_uu_lll ha_eueu_lll za_ex
#   Target:    dang sle feng breu hle dya gre dle meh fyé wuh bong cur ceuh noh kyé sor var har nlu hleu zé
#   Predicted: dang sle feng breu hle dya gre dle meh fyé wuh bong cur ceuh noh kyé sor var har nlu hleu zé
#   CER: 0.00%, WER: 0.00%
#
# Example 40:
#   Source:    e_ng la_ee_lll ma_eueu_yyy sa_ex_rrr ra_uu_lll ga_eueu_yyy sa_ee_ng na_ee_yyy da_oo_yyy ra_uu_hh va_pamaeh o_ng sa_oo_rr ba_rr ja_rr opat sa_rr ka_oo xa_lll
#   Target:    eng lle myeu sré rlu gyeu seng nye dyo ruh v ong sor bar jar 4 sar ko xla
#   Predicted: eng lle myeu sré rlu gyeu seng nye dyo ruh v ong sor bar jar 4 sar ko xla
#   CER: 0.00%, WER: 0.00%
#
# Example 41:
#   Source:    nya_ii_hh sa_eueu_rr ya_pamaeh ja_oo_hh e_rr sya_rr pa_rrr da_ii_rrr na_ex_yyy ka_uu nga_oo_ng ca_ex_ng ga_oo la_ii_rr ka_uu_hh va_ex_hh nga_eueu sya_uu_ng qa_ee_rr ba_ee_rr na_uu_hh
#   Target:    nyih seur y joh er syar pra dri nyé ku ngong céng go lir kuh véh ngeu syung qer ber nuh
#   Predicted: nyih seur y joh er syar pra dri nyé ku ngong céng go lir kuh véh ngeu syung qer ber nuh
#   CER: 0.00%, WER: 0.00%
#
# Example 42:
#   Source:    eu
#   Target:    eu
#   Predicted: eu
#   CER: 0.00%, WER: 0.00%
#
# Example 43:
#   Source:    sa_oo ha_uu_yyy da_oo ma_ii_yyy ma_ee_yyy la fa_eueu_rr ha_rrr na_uu_hh da_uu ca_uu_lll ra_pamaeh
#   Target:    so hyu do myi mye la feur hra nuh du clu r
#   Predicted: so hyu do myi mye la feur hra nuh du clu r
#   CER: 0.00%, WER: 0.00%
#
# Example 44:
#   Source:    wa_eueu_ng sa_ii_rrr qa_uu da_oo_hh ma_uu ra_hh la_oo_yyy xa_lll nga_oo_ng fa_eueu ya ha_ee ja_ex_lll da_oo za_eueu da_oo_rr wa_uu ca_ex ba_ex_ng ra_ii_rrr ga_eueu_lll na_eueu_ng ta_uu_lll sa_hh fa_ex_rr
#   Target:    weung sri qu doh mu rah lyo xla ngong feu ya he jlé do zeu dor wu cé béng rri gleu neung tlu sah fér
#   Predicted: weung sri qu doh mu rah lyo xla ngong feu ya he jlé do zeu dor wu cé béng rri gleu neung tlu sah
#   CER: 3.95%, WER: 4.00%
#
# Example 45:
#   Source:    ma_ii_lll va_eueu_ng ja_ng ha_ii_ng ca_ee qa_ex_ng da_uu_yyy ra_uu_ng la_ii_rr
#   Target:    mli veung jang hing ce qéng dyu rung lir
#   Predicted: mli veung jang hing ce qéng dyu rung lir
#   CER: 0.00%, WER: 0.00%
#
# Example 46:
#   Source:    a_rr
#   Target:    ar
#   Predicted: ar
#   CER: 0.00%, WER: 0.00%
#
# Example 47:
#   Source:    sa_hh va_ii_hh sa_uu_hh
#   Target:    sah vih suh
#   Predicted: sah vih suh
#   CER: 0.00%, WER: 0.00%
#
# Example 48:
#   Source:    ga_eueu_yyy sya_oo_hh ga_eueu_hh ya_ex fa_ex_ng a_rr za_eueu_ng na_ee_rr ya_ex_rrr ba_rr va_ee pa_yyy eu
#   Target:    gyeu syoh geuh yé féng ar zeung ner yré bar ve pya eu
#   Predicted: gyeu syoh geuh yé féng ar zeung ner yré bar ve pya eu
#   CER: 0.00%, WER: 0.00%
#
# Example 49:
#   Source:    nya na_ee ja_ee_ng xa_ii_ng ma_ii_yyy ra_eueu_yyy ma_eueu_yyy wa_oo na_ii_ng sa_eueu_lll
#   Target:    nya ne jeng xing myi ryeu myeu wo ning sleu
#   Predicted: nya ne jeng xing myi ryeu myeu wo ning sleu
#   CER: 0.00%, WER: 0.00%
#
# Example 50:
#   Source:    ha_eueu_yyy da_uu_rrr pa_pamaeh kha_oo nya_uu_hh ma_ii_lll ca_oo_ng ha_ee_yyy ca_ii_hh ya_ee_hh da_rr za_uu_hh ya_ex_hh da_uu_ng ra_eueu_yyy la_uu_hh
#   Target:    hyeu dru p kho nyuh mli cong hye cih yeh dar zuh yéh dung ryeu luh
#   Predicted: hyeu dru p kho nyuh mli cong hye cih yeh dar zuh yéh dung ryeu luh
#   CER: 0.00%, WER: 0.00%
#
# Example 51:
#   Source:    sa_ex_yyy ta_pamaeh za_eueu ha_ee_hh
#   Target:    syé t zeu heh
#   Predicted: syé t zeu heh
#   CER: 0.00%, WER: 0.00%
#
# Example 52:
#   Source:    nga_hh za_yyy na_ng ta_yyy nga_ee_hh pa_ee_hh da_pamaeh
#   Target:    ngah zya nang tya ngeh peh d
#   Predicted: ngah zya nang tya ngeh peh d
#   CER: 0.00%, WER: 0.00%
#
# Example 53:
#   Source:    o_rr ha_ex_rrr ma_uu_yyy za_ii_rr da_oo_rrr
#   Target:    or hré myu zir dro
#   Predicted: or hré myu zir dro
#   CER: 0.00%, WER: 0.00%
#
# Example 54:
#   Source:    ta_ii_lll sya_ee_hh wa_uu da_ii_ng da_ee va_ex_hh ca_oo_rr sa_ii_yyy ta_ii_yyy sa_uu_hh sa_uu_ng sa_eueu_lll ca_oo_hh wa_eueu_ng ba_uu_rr ha_oo_lll sa_ii_rr sya_hh ba_ee_hh ya_rrr kha_ex_hh sa_ii
#   Target:    tli syeh wu ding de véh cor syi tyi suh sung sleu coh weung bur hlo sir syah beh yra khéh si
#   Predicted: tli syeh wu ding de véh cor syi tyi suh sung sleu coh weung bur hlo sir syah beh yra khéh si
#   CER: 0.00%, WER: 0.00%
#
# Example 55:
#   Source:    hiji nya_ee_ng xa_ee ca_ii_rrr nga_uu_rr ma_ex_rr wa_hh
#   Target:    1 nyeng xe cri ngur mér wah
#   Predicted: 1 nyeng xe cri ngur mér wah
#   CER: 0.00%, WER: 0.00%
#
# Example 56:
#   Source:    ya_oo_ng na_ee_hh pa_uu_hh ha_ex_hh sa_ii_yyy ha_oo ra_yyy la_ii_lll ra_ii_rrr
#   Target:    yong neh puh héh syi ho rya lli rri
#   Predicted: yong neh puh héh syi ho rya lli rri
#   CER: 0.00%, WER: 0.00%
#
# Example 57:
#   Source:    ya_hh ba_ex_rr ta_ee_ng ja_uu da_uu_rrr la_uu_yyy ca_yyy nya_ii_ng da_ii_rrr ma_ee_yyy
#   Target:    yah bér teng ju dru lyu cya nying dri mye
#   Predicted: yah bér teng ju dru lyu cya nying dri mye
#   CER: 0.00%, WER: 0.00%
#
# Example 58:
#   Source:    la_ex_rr ca_ee_hh ya_ee ma_ii_ng ha_ee_yyy ja_ex_ng da_ee_yyy
#   Target:    lér ceh ye ming hye jéng dye
#   Predicted: lér ceh ye ming hye jéng dye
#   CER: 0.00%, WER: 0.00%
#
# Example 59:
#   Source:    ha_uu ha_uu_yyy za_ii_rr ma ga_ex_ng
#   Target:    hu hyu zir ma géng
#   Predicted: hu hyu zir ma géng
#   CER: 0.00%, WER: 0.00%
#
# Example 60:
#   Source:    za_ee_ng za_hh va_eueu_rr
#   Target:    zeng zah veur
#   Predicted: zeng zah veur
#   CER: 0.00%, WER: 0.00%
#
# Example 61:
#   Source:    ga_ii_ng ha_rrr fa_rr ba_ii_hh la_ii_rr ha_uu pa_uu_hh ja_eueu_hh ta_ii_lll pa_uu_yyy ya_eueu_yyy va_ee_ng ca_uu_rr
#   Target:    ging hra far bih lir hu puh jeuh tli pyu yyeu veng cur
#   Predicted: ging hra far bih lir hu puh jeuh tli pyu yyeu veng cur
#   CER: 0.00%, WER: 0.00%
#
# Example 62:
#   Source:    va_oo ha_eueu_yyy ba_eueu_hh ga_uu_rrr na_uu sa_ex_lll pa_ii_hh
#   Target:    vo hyeu beuh gru nu slé pih
#   Predicted: vo hyeu beuh gru nu slé pih
#   CER: 0.00%, WER: 0.00%
#
# Example 63:
#   Source:    ba_yyy ta_oo ma_oo_lll ha_ii ra_lll ha_hh ta_eueu_yyy sa_oo_lll sa_ii_rrr fa la_oo_ng fa_lll da_ee_hh da_ii_ng
#   Target:    bya to mlo hi rla hah tyeu slo sri fa long fla deh ding
#   Predicted: bya to mlo hi rla hah tyeu slo sri fa long fla deh ding
#   CER: 0.00%, WER: 0.00%
#
# Example 64:
#   Source:    ga_ng
#   Target:    gang
#   Predicted: gang
#   CER: 0.00%, WER: 0.00%
#
# Example 65:
#   Source:    ta_eueu_hh ca_oo_rrr sa_rr ta_pamaeh wa_uu_rr ha_ee_hh fa_uu_lll ra_oo_hh fa_ex_rrr va_ex wa i_ng
#   Target:    teuh cro sar t wur heh flu roh fré vé wa ing
#   Predicted: teuh cro sar t wur heh flu roh fré vé wa ing
#   CER: 0.00%, WER: 0.00%
#
# Example 66:
#   Source:    na_ee_rr pa_pamaeh na_ex_lll sa_ee_hh fa_ii_ng va_ex_rr ja_uu_rr nga_eueu_ng ba_ii_rr ba_rr xa_ex_rr da ra_uu ka_ex_ng ba_uu_hh nga_ii_hh sa_eueu_rrr
#   Target:    ner p nlé seh fing vér jur ngeung bir bar xér da ru kéng buh ngih sreu
#   Predicted: ner p nlé seh fing vér jur ngeung bir bar xér da ru kéng buh ngih sreu
#   CER: 0.00%, WER: 0.00%
#
# Example 67:
#   Source:    ja_ee ja_eueu_rr ka_oo_rrr sa_ex ba_uu_ng ka_ii_rrr wa_oo_lll kha_ee
#   Target:    je jeur kro sé bung kri wlo khe
#   Predicted: je jeur kro sé bung kri wlo khe
#   CER: 0.00%, WER: 0.00%
#
# Example 68:
#   Source:    ga_oo_rrr ma_ex ka_oo pa_ee ma_oo_hh ba_oo_rrr za_oo_rr da_rr ba_ex_rr wa_ee_rr na_eueu_rr sa_ex sa pa_ii_rr ra_uu_ng na_eueu_hh ha_uu_rr
#   Target:    gro mé ko pe moh bro zor dar bér wer neur sé sa pir rung neuh hur
#   Predicted: gro mé ko pe moh bro zor dar bér wer neur sé sa pir rung neuh hur
#   CER: 0.00%, WER: 0.00%
#
# Example 69:
#   Source:    ya_ng va_uu_hh pa_ii_ng ba_eueu_yyy ja_ex_hh ga_ex_ng va_uu_ng
#   Target:    yang vuh ping byeu jéh géng vung
#   Predicted: yang vuh ping byeu jéh géng vung
#   CER: 0.00%, WER: 0.00%
#
# Example 70:
#   Source:    na_oo_hh ca_uu_hh la_ng ra_oo_lll pa_uu_rr fa_uu_rrr sa_uu_rr ra_uu_lll ha_eueu wa_rrr za_oo ca_eueu_hh ka_eueu_lll za_ii ka_uu_hh nga_uu_hh
#   Target:    noh cuh lang rlo pur fru sur rlu heu wra zo ceuh kleu zi kuh nguh
#   Predicted: noh cuh lang rlo pur fru sur rlu heu wra zo ceuh kleu zi kuh nguh
#   CER: 0.00%, WER: 0.00%
#
# Example 71:
#   Source:    pa_uu_yyy wa_eueu_lll ka_eueu_rrr sa_ex_yyy da_rrr ha_oo_ng nga_eueu_ng ta_uu pa_ii_ng ga_oo da_eueu_rrr ra_ee_rr ka_ex_hh na_yyy u_rr sya_oo_ng fa_eueu_ng pa_ex_hh nya_ii_hh na_rr ga_lll qa_ii ma_ee_rr
#   Target:    pyu wleu kreu syé dra hong ngeung tu ping go dreu rer kéh nya ur syong feung péh nyih nar gla qi mer
#   Predicted: pyu wleu kreu syé dra hong ngeung tu ping go dreu rer kéh nya ur syong feung péh nyih nar gla qi mer
#   CER: 0.00%, WER: 0.00%
#
# Example 72:
#   Source:    qa_eueu_hh
#   Target:    qeuh
#   Predicted: qeuh
#   CER: 0.00%, WER: 0.00%
#
# Example 73:
#   Source:    ta_ii_rr qa_hh kha_eueu_ng ca_uu_lll ba_ex_ng sa_ex_rr ya_oo_rr nga_eueu_hh fa_ex_rrr ta_oo_ng ha_eueu_rr ra_pamaeh ga_ex_yyy ga_oo_ng sa_eueu_ng sya_oo_rr ba_oo
#   Target:    tir qah kheung clu béng sér yor ngeuh fré tong heur r gyé gong seung syor bo
#   Predicted: tir qah kheung clu béng sér yor ngeuh fré tong heur r gyé gong seung syor bo
#   CER: 0.00%, WER: 0.00%
#
# Example 74:
#   Source:    wa_ex_lll na_oo da_uu ta_oo ga_ng ma_ii_rrr ma_rrr na_pamaeh ha_uu_hh ja_oo_rr ma_eueu_yyy za_ee_hh na_oo_hh wa_eueu_ng xa_hh pa_ex_hh ga_uu_rrr na_uu_rrr ba_ii_ng
#   Target:    wlé no du to gang mri mra n huh jor myeu zeh noh weung xah péh gru nru bing
#   Predicted: wlé no du to gang mri mra n huh jor myeu zeh noh weung xah péh gru nru bing
#   CER: 0.00%, WER: 0.00%
#
# Example 75:
#   Source:    fa_eueu_ng ta_ii ja_ex_lll nga_oo nya_hh ga_ii_rrr ja_uu_ng ja_ii_lll nga_ee sa_oo ha_ex_ng kha_hh la_eueu_hh nya ka_ee_rrr ca_ex ga_ee_lll va_ii_rr da_ee_ng da_ee_rrr ya_uu_rrr ga_ex_hh pa_eueu_yyy ya_ee_rrr
#   Target:    feung ti jlé ngo nyah gri jung jli nge so héng khah leuh nya kre cé gle vir deng dre yru géh pyeu yre
#   Predicted: feung ti jlé ngo nyah gri jung jli nge so héng khah leuh nya kre cé gle vir deng dre yru géh pyeu yre
#   CER: 0.00%, WER: 0.00%
#
# Example 76:
#   Source:    ta_eueu pa_ex_lll fa_ee_lll wa_hh ba_hh ka_ex va_ex_rr qa_ii_hh da_ee_ng wa_uu_lll fa_ii_yyy la_eueu_hh dua ja_ee_ng pa_ex_yyy da_lll wa_pamaeh
#   Target:    teu plé fle wah bah ké vér qih deng wlu fyi leuh 2 jeng pyé dla w
#   Predicted: teu plé fle wah bah ké vér qih deng wlu fyi leuh 2 jeng pyé dla w
#   CER: 0.00%, WER: 0.00%
#
# Example 77:
#   Source:    ra_eueu_rrr
#   Target:    rreu
#   Predicted: rreu
#   CER: 0.00%, WER: 0.00%
#
# Example 78:
#   Source:    da_oo ta_oo_hh da_ex_rrr qa_ex_rr ka_eueu_lll va_ng sya_oo_hh pa_uu_ng ma_uu_rr ta_uu_rrr nya_rr ba_ii_rrr ja_ex_ng pa_hh ka la_rrr ca_eueu_rr pa_uu_lll ta_rr nya_ex_ng na_oo da_ex_ng
#   Target:    do toh dré qér kleu vang syoh pung mur tru nyar bri jéng pah ka lra ceur plu tar nyéng no déng
#   Predicted: do toh dré qér kleu vang syoh pung mur tru nyar bri jéng pah ka lra ceur plu tar nyéng no déng
#   CER: 0.00%, WER: 0.00%
#
# Example 79:
#   Source:    na_oo ba_uu_rrr sya_ee_rr qa_ee ha_ee_rr da_oo_rrr ra_rr ta_ee_rr ra_ii_rr pa_rr fa_uu va_oo ra_oo ma_ex_ng ka_ii_lll ga_ii_ng ma_eueu_lll sya_ex_ng da_ex ba_pamaeh ra_eueu_yyy va_rr kha_ex da_hh
#   Target:    no bru syer qe her dro rar ter rir par fu vo ro méng kli ging mleu syéng dé b ryeu var khé dah
#   Predicted: no bru syer qe her dro rar ter rir par fu vo ro méng kli ging mleu syéng dé b ryeu var khé dah
#   CER: 0.00%, WER: 0.00%
#
# Example 80:
#   Source:    nya_uu ya_ex_hh sa_pamaeh sa_yyy ha_eueu_rr ga_ex_ng wa_oo_ng pa_uu_hh ja_eueu_rr la_oo_hh la_ee_rr ha_uu na_oo_ng ma_eueu_hh na_ex pa_ex_ng fa_oo_lll da_uu_yyy na_oo_rr ya_eueu va_ng ga_yyy ca_ii_rrr
#   Target:    nyu yéh s sya heur géng wong puh jeur loh ler hu nong meuh né péng flo dyu nor yeu vang gya cri
#   Predicted: nyu yéh s sya heur géng wong puh jeur loh ler hu nong meuh né péng flo dyu nor yeu vang gya cri
#   CER: 0.00%, WER: 0.00%
#
# Example 81:
#   Source:    e_rr na_oo_hh ga_ex_ng ja_yyy a_hh wa_ee_rr za_uu_rr ya_uu_hh za_uu_hh sya_ex za_ex_ng wa_uu_ng da_ii_hh ba_ii_yyy
#   Target:    er noh géng jya ah wer zur yuh zuh syé zéng wung dih byi
#   Predicted: er noh géng jya ah wer zur yuh zuh syé zéng wung dih byi
#   CER: 0.00%, WER: 0.00%
#
# Example 82:
#   Source:    ja_oo_yyy
#   Target:    jyo
#   Predicted: jyo
#   CER: 0.00%, WER: 0.00%
#
# Example 83:
#   Source:    na_yyy na_hh ya_oo_rrr nga_ii_rr wa_eueu_yyy la_ee na_ex_lll fa_pamaeh da_ee_lll pa_ii_ng pa_hh ja_eueu
#   Target:    nya nah yro ngir wyeu le nlé f dle ping pah jeu
#   Predicted: nya nah yro ngir wyeu le nlé f dle ping pah jeu
#   CER: 0.00%, WER: 0.00%
#
# Example 84:
#   Source:    ma_ee_hh ya_oo_lll wa_uu_yyy ja_ee_rrr ha_oo_lll ba_uu_lll sya_ee na_rr wa_rrr nya_uu ja_oo ya_ng wa_ii_hh sya_pamaeh ha_ii ga_hh ca_eueu_rr ma_ex va_yyy
#   Target:    meh ylo wyu jre hlo blu sye nar wra nyu jo yang wih sy hi gah ceur mé vya
#   Predicted: meh ylo wyu jre hlo blu sye nar wra nyu jo yang wih sy hi gah ceur mé vya
#   CER: 0.00%, WER: 0.00%
#
# Example 85:
#   Source:    sa_oo_lll la_ee_hh sa_ii_ng ba_ii_rr wa_eueu_rr sa_ex_hh ca_ee_rr da_oo ca_oo_hh ja_ee_rrr ma_uu_hh la_ii_yyy ga_eueu
#   Target:    slo leh sing bir weur séh cer do coh jre muh lyi geu
#   Predicted: slo leh sing bir weur séh cer do coh jre muh lyi geu
#   CER: 0.00%, WER: 0.00%
#
# Example 86:
#   Source:    za_eueu ra_ee_rr ga_ex ga_ii_hh va_eueu_ng da_eueu_rrr ga_ex_rr wa_uu_hh
#   Target:    zeu rer gé gih veung dreu gér wuh
#   Predicted: zeu rer gé gih veung dreu gér wuh
#   CER: 0.00%, WER: 0.00%
#
# Example 87:
#   Source:    ma_uu_yyy wa_rrr nya_uu_rr na_ee_hh nga_ee_rr ma_eueu na_ee_lll da_ii lima na_ex_yyy ma_eueu_rr ga_ee_yyy
#   Target:    myu wra nyur neh nger meu nle di 5 nyé meur gye
#   Predicted: myu wra nyur neh nger meu nle di 5 nyé meur gye
#   CER: 0.00%, WER: 0.00%
#
# Example 88:
#   Source:    nga_oo_ng da_ex ca_ex va_lll za_ee pa_ex ba sya_hh fa_eueu_rr wa_ii_yyy ba_ex_yyy na_eueu_hh sa_ex_rr wa_ex nya_ii_rr na_oo_rr ka_oo_lll ga_lll ya_yyy
#   Target:    ngong dé cé vla ze pé ba syah feur wyi byé neuh sér wé nyir nor klo gla yya
#   Predicted: ngong dé cé vla ze pé ba syah feur wyi byé neuh sér wé nyir nor klo gla yya
#   CER: 0.00%, WER: 0.00%
#
# Example 89:
#   Source:    ca_eueu_ng ta_ex_rr ma_ex pa_ee_rr ma_ii_rrr ya_ee_lll ca_oo_rr la_ee_hh ba_eueu_yyy pa na_ii_rr da_ex_hh ja_yyy da_ex_rr ma_ee_ng ba_ex_rr na_pamaeh wa_ex_ng wa_ii_rr nya_hh fa_rrr ra_oo_rrr ha_ex_yyy
#   Target:    ceung tér mé per mri yle cor leh byeu pa nir déh jya dér meng bér n wéng wir nyah fra rro hyé
#   Predicted: ceung tér mé per mri yle cor leh byeu pa nir déh jya dér meng bér n wéng wir nyah fra rro hyé
#   CER: 0.00%, WER: 0.00%
#
# Example 90:
#   Source:    ga_ex_yyy ta_eueu_rr sa_ee ca_ii_yyy ya_ee_hh ka_ex_rr wa_ee_ng xa_uu za_rr xa_oo
#   Target:    gyé teur se cyi yeh kér weng xu zar xo
#   Predicted: gyé teur se cyi yeh kér weng xu zar xo
#   CER: 0.00%, WER: 0.00%
#
# Example 91:
#   Source:    ja_uu_yyy pa_eueu ta_eueu_lll ja_ex ca_oo_lll ja kha_pamaeh ka_ex_rr ha_rr ja_rrr ha_ee_ng ra_pamaeh ba_ii nya_eueu_rr i_hh pa_uu ha_ee_rrr ha_eueu_rrr ga_uu_yyy fa_lll sa_ex_ng ra_ee_rr na_eueu_lll
#   Target:    jyu peu tleu jé clo ja kh kér har jra heng r bi nyeur ih pu hre hreu gyu fla séng rer nleu
#   Predicted: jyu peu tleu jé clo ja kh kér har jra heng r bi nyeur ih pu hre hreu gyu fla séng rer nleu
#   CER: 0.00%, WER: 0.00%
#
# Example 92:
#   Source:    wa_eueu_ng ja_ee_hh ja_ii_ng ha_eueu_yyy
#   Target:    weung jeh jing hyeu
#   Predicted: weung jeh jing hyeu
#   CER: 0.00%, WER: 0.00%
#
# Example 93:
#   Source:    pa_rr va_eueu_rr
#   Target:    par veur
#   Predicted: par veur
#   CER: 0.00%, WER: 0.00%
#
# Example 94:
#   Source:    ha_ee_lll
#   Target:    hle
#   Predicted: hle
#   CER: 0.00%, WER: 0.00%
#
# Example 95:
#   Source:    kha_ex kha_ee_hh ya_oo_lll ja_ii za_eueu_ng xa_hh nya ja_rr ja_uu_yyy ma_ee_rrr sa_ex_lll qa_eueu ja_uu_hh kha na_ii_hh ca_uu_yyy
#   Target:    khé kheh ylo ji zeung xah nya jar jyu mre slé qeu juh kha nih cyu
#   Predicted: khé kheh ylo ji zeung xah nya jar jyu mre slé qeu juh kha nih cyu
#   CER: 0.00%, WER: 0.00%
#
# Example 96:
#   Source:    ta_ex_rrr va_ii ya_ii_lll fa_eueu_hh ha_ex za_eueu_ng la_rrr ba_hh sa_ex_lll la_oo_rrr nya_uu_hh ba_ii_lll ba_eueu ga_eueu_ng da ta_ex_ng ra_oo_lll o_rr wa_eueu_lll xa_lll ba_ii_rr da_uu_rr
#   Target:    tré vi yli feuh hé zeung lra bah slé lro nyuh bli beu geung da téng rlo or wleu xla bir dur
#   Predicted: tré vi yli feuh hé zeung lra bah slé lro nyuh bli beu geung da téng rlo or wleu xla bir dur
#   CER: 0.00%, WER: 0.00%
#
# Example 97:
#   Source:    dua pa_ee_lll nga_oo_ng pa_oo_ng wa_ee_rrr ja_ee_ng la_uu_yyy wa_uu_rrr sa_oo_lll na_ii_yyy da_eueu_yyy ka_eueu_lll sa_ii_lll nya_rr za_rr da_ii_ng la_eueu_rr va_oo_hh i_hh
#   Target:    2 ple ngong pong wre jeng lyu wru slo nyi dyeu kleu sli nyar zar ding leur voh ih
#   Predicted: 2 ple ngong pong wre jeng lyu wru slo nyi dyeu kleu sli nyar zar ding leur voh ih
#   CER: 0.00%, WER: 0.00%
#
# Example 98:
#   Source:    da_rr xa_ng ra_rrr sa_yyy ra_uu_rrr ta_eueu_rrr la_oo_lll za_ii na_eueu_hh nya_ex_ng ga_eueu_lll
#   Target:    dar xang rra sya rru treu llo zi neuh nyéng gleu
#   Predicted: dar xang rra sya rru treu llo zi neuh nyéng gleu
#   CER: 0.00%, WER: 0.00%
#
# Example 99:
#   Source:    kha_eueu_ng ka_ng ra_ex_rr ya_ee_hh da_ex_lll ya_eueu_hh nya_uu_rr
#   Target:    kheung kang rér yeh dlé yeuh nyur
#   Predicted: kheung kang rér yeh dlé yeuh nyur
#   CER: 0.00%, WER: 0.00%
#
# Example 100:
#   Source:    ma_ex_ng ja_ii_yyy nga_uu xa_ee ba_ee_rrr ja_ee_rrr wa_ee_hh salapan ga_ee_ng fa_ee_rrr qa_ex_ng ga_oo_yyy la_rr ja_oo_lll ta_uu za_ex_ng fa_oo_rr ra_uu_ng fa_ex ja_uu_ng ja_ee va_rrr
#   Target:    méng jyi ngu xe bre jre weh 9 geng fre qéng gyo lar jlo tu zéng for rung fé jung je vra
#   Predicted: méng jyi ngu xe bre jre weh 9 geng fre qéng gyo lar jlo tu zéng for rung fé jung je vra
#   CER: 0.00%, WER: 0.00%
#
# CER: 0.25%, WER: 0.25%

# %%
# Save only the model weights
torch.save(model.state_dict(), "seq2seq_model_bi_attention_10k.pt")

# %%
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    # Optionally, save epoch, loss, etc.
    'epoch': epoch,
    'loss': loss,
}, "seq2seq_checkpoint_bi_attention.pt")
